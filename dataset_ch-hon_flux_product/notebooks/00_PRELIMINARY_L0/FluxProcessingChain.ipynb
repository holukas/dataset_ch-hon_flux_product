# %% [markdown]
# ![lop](../../images/logo_diive1_128px.png)

# %% [markdown]
# <span style='font-size:40px; display:block;'>
# <b>
#     Flux Processing Chain
# </b>
# </br>
#
# </span>
# <p>Post-processing of EddyPro <i>_fluxnet_</i> output files</p>

# %% [markdown]
# ---
# **Notebook version**: `11.0` (5 Dec 2025)
# **Author**: Lukas Hörtnagl (holukas@ethz.ch)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ℹ️BACKGROUND

# %% [markdown]
# - This notebook demonstrates part of the flux post-processing used for fluxes from Swiss FluxNet research stations
# - For a description of the different flux levels, see [Flux Processing Chain](https://www.swissfluxnet.ethz.ch/index.php/data/ecosystem-fluxes/flux-processing-chain/) on the Swiss FluxNet homepage
# - There is also a good overview here: [Flux Processing Chain described for CH-CHA Flux Product](https://holukas.github.io/dataset_ch-cha_flux_product/Overview.html#flux-processing-chain)
# - Flux calculations (Level-1) in EddyPro were done in a previous step, this is post-processing only
# - This notebook uses the calculated fluxes (Level-1) and applies several post-processing steps:
#     - Quality flag extension (Level-2)
#     - Storage correction (Level-3.1)
#     - Outlier removal (Level-3.2)
#     - USTAR filtering (Level-3.3) - needs *known* thresholds from separate analysis, e.g. from FLUXNET or from REddyProc
#     - Gap-filling (Level-4.1) for flux using multiple methods ([MDS](../GapFilling/FluxMDSGapFilling.ipynb), [long-term random forest](../GapFilling/LongTermRandomForestGapFilling.ipynb))
# - Other flux levels are currently not produced in this example:
#     - NEE Partitioning (Level-4.2)
#
# **Important**
# - Flux variable names in the input files should follow the [FLUXNET convention](https://fluxnet.org/data/fluxnet2015-dataset/fullset-data-product/)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ⭕GENERAL SETTINGS

# %% [markdown]
# ## Flux variable
# `FLUXVAR` is the name of the flux variable in the data files. In the EddyPro `_fluxnet_` output files, the flux variables we primarily use are:
#   - `FC` ... CO2 flux, becomes `NEE` after storage correction (Level-3.1)
#   - `LE` ... Latent heat flux (water)
#   - `H` ... Sensible heat flux
#   - `FN2O` ... Nitrous oxide flux
#   - `FCH4` ... Methane flux
#
# There are more flux variables in the output file, but we rarely need them:
#   - `FH2O` ... H2O flux, very important but it is the same as `ET` and `LE` but with different units
#   - `ET` ... Evapotranspiration, very important but it is the same as `FH2O` and `LE` but with different units. We can easily calculate `ET` from `LE` later, e.g. in `diive` as shown in the notebook [Calculate ET from LE](../CalculateVariable/Calculate_ET_from_LE.ipynb).
#   - `TAU` ... Momentum flux, a measure of the turbulent transfer of momentum between the land surface and the atmosphere
#
# Set the name of the flux variable in the output file(s), must use the FLUXNET naming convention, e.g. FC, FH2O, LE, ET, H, FN2O, FCH4:

# %%
FLUXVAR = "FC"

# %% [markdown]
# ## Site location
# - Latitude and longitude of the site where data were recorded. This info is mainly used to calculate potential radiation, which is then used to divide the dataset into daytime and nighttime data.
# - UTC offset of the timestamp used in the dataset, important for calculating potential radiation for this location with the correct timestamp.

# %%
SITE_LAT = 47.41887
SITE_LON = 8.491318
UTC_OFFSET = 1  # Time stamp offset in relation to UTC, e.g. 1 for UTC+01:00 (CET), important for the calculation of potential radiation for detecting daytime and nighttime

# %% [markdown]
# ## Daytime/nighttime
# - Threshold for potential radiation in `W m-2`, records below threshold are considered nighttime

# %%
NIGHTTIME_THRESHOLD = 20

# %% [markdown]
# ## Quality requirements
# - `DAYTIME_ACCEPT_QCF_BELOW = 2` accepts high- (`QCF=0`) and medium-quality (`QCF=1`) fluxes for *daytime*, rejects low-quality (`QCF=2`) fluxes
# - `NIGHTTIMETIME_ACCEPT_QCF_BELOW = 1` accepts high-quality (`QCF=0`) fluxes for *nighttime*, rejects medium-quality (`QCF=1`) and low-quality (`QCF=2`) fluxes
# - This strict quality-filtering removes a lot of data points during nighttime

# %%
DAYTIME_ACCEPT_QCF_BELOW = 2
NIGHTTIMETIME_ACCEPT_QCF_BELOW = 2

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # IMPORTS

# %% [markdown]
# - This notebook uses `diive` ([source code](https://github.com/holukas/diive)) to check eddy covariance fluxes for quality

# %%
import importlib.metadata
import warnings
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats
import seaborn as sns

from diive.core.dfun.stats import sstats  # Time series stats
from diive.core.io.files import save_parquet, load_parquet
from diive.core.plotting.timeseries import TimeSeries  # For simple (interactive) time series plotting
from diive.pkgs.flux.hqflux import analyze_highest_quality_flux
from diive.pkgs.fluxprocessingchain.fluxprocessingchain import FluxProcessingChain
from diive.pkgs.fluxprocessingchain.fluxprocessingchain import LoadEddyProOutputFiles

warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
# Out:
# diive version: v0.91.0

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # DOCSTRING for `FluxProcessingChain`

# %%
# help(FluxProcessingChain)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # LOAD DATA (2 options)

# %% [markdown]
# - It is possible to load data from (multiple) EddyPro _fluxnet_ output files (data from files will be merged), or directly from one single [parquet](https://parquet.apache.org/) file.
# - parquet files are a good option for large datasets because they load and save much faster than when using conventional CSV files.
# - For large datasets, it makes sense to first load and merge data from the original EddyPro _fluxnet_ output files, then convert the merged data to one single parquet file and then use this file as input file.

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Load data from single or multiple EddyPro *_fluxnet_* output files
# - Used to read data from the EddyPro _fluxnet_ output files
# - Found files will be merged together into one single dataframe (`maindf`)

# %% [markdown]
# If you want to search for EddyPro _fluxnet_ files in specific locations, you can specify multiple folders here:

# %%
# # Folder(s) where input file(s) are located
# SOURCEDIRS = [r'example_data/']

# %%
# ep = LoadEddyProOutputFiles(sourcedir=SOURCEDIRS, filetype='EDDYPRO-FLUXNET-CSV-30MIN')
# ep.searchfiles()
# ep.loadfiles()
# maindf = ep.maindf
# metadata = ep.metadata

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Load data from `parquet` file
# - Can be used to continue a previous session where another flux variable was already post-processed
# - For example, if you have already post-processed CO2 flux and now want to post-process H2O flux
# - Also detects time resolution of time series, this info was lost when saving to the parquet file

# %% [markdown]
# If you want to load data directly from a specific parquet file, you can specify its name and location here:

# %%
SOURCEDIR = r"..\0_data\OPENLAG-IRGA-Level-0_fluxnet_2024-2026.03"
FILENAME = r"FLUXES_L0_ALL.parquet"
FILEPATH = Path(SOURCEDIR) / FILENAME
print(f"Data will be loaded from the following file:\n{FILEPATH}")
# Out:
# Data will be loaded from the following file:
# ..\0_data\OPENLAG-IRGA-Level-0_fluxnet_2024-2026.03\FLUXES_L0_ALL.parquet

# %%
maindf = load_parquet(filepath=FILEPATH)
# Out:
# Loaded .parquet file ..\0_data\OPENLAG-IRGA-Level-0_fluxnet_2024-2026.03\FLUXES_L0_ALL.parquet (0.109 seconds).
#     --> Detected time resolution of <30 * Minutes> / 30min

# %% [markdown]
# </br>

# %% [markdown]
# ## REMOVE WIND DIRECTIONS

# %%
maindf['WD']
# Out:
# TIMESTAMP_MIDDLE
# 2024-02-06 19:15:00    172.713
# 2024-02-06 19:45:00    180.467
# 2024-02-06 20:15:00    183.015
# 2024-02-06 20:45:00    189.732
# 2024-02-06 21:15:00    196.681
#                         ...
# 2026-03-31 22:45:00    211.009
# 2026-03-31 23:15:00    243.715
# 2026-03-31 23:45:00    178.888
# 2026-04-01 00:15:00    219.056
# 2026-04-01 00:45:00    174.930
# Freq: 30min, Name: WD, Length: 37644, dtype: float64

# %%
locs = (maindf['WD'] > 180) & (maindf['WD'] < 350)
import numpy as np
maindf.loc[locs, :] = np.nan
maindf.loc[locs, :]
# Out:
#                      AIR_MV  AIR_DENSITY  AIR_RHO_CP  AIR_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  W_ITC  W_ITC_TEST  WBOOST_APPLIED  WPL_APPLIED  ZL  ZL_UNCORR
# TIMESTAMP_MIDDLE                                                                                ...
# 2024-02-06 19:45:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2024-02-06 20:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2024-02-06 20:45:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2024-02-06 21:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2024-02-06 21:45:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# ...                     ...          ...         ...     ...         ...                   ...  ...    ...         ...             ...          ...  ..        ...
# 2026-03-31 21:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2026-03-31 22:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2026-03-31 22:45:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2026-03-31 23:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
# 2026-04-01 00:15:00     NaN          NaN         NaN     NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN NaN        NaN
#
# [18725 rows x 480 columns]

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 3: Load example data

# %%
# from diive.configs.exampledata import load_exampledata_EDDYPRO_FLUXNET_CSV_30MIN
# maindf, metadata = load_exampledata_EDDYPRO_FLUXNET_CSV_30MIN()

# %% [markdown]
# </br>

# %% [markdown]
# ## (Optional) Restrict data to time range

# %%
# Restrict data range
# maindf = maindf.loc[(maindf.index.year >= 2022) & (maindf.index.year <= 2024)].copy()  # One year
# maindf = maindf.loc[(maindf.index.year >= 2022) & (maindf.index.year <= 2022) & (maindf.index.month >= 6) & (maindf.index.month <= 7)].copy()

# %% [markdown]
# </br>

# %% [markdown]
# ## Check data

# %%
display(maindf.head(3))
display(maindf.tail(3))
display(sstats(maindf[FLUXVAR]))
# Out:
#                        AIR_MV  AIR_DENSITY  AIR_RHO_CP   AIR_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  W_ITC  W_ITC_TEST  WBOOST_APPLIED  WPL_APPLIED        ZL  ZL_UNCORR
# TIMESTAMP_MIDDLE                                                                                   ...
# 2024-02-06 19:15:00  0.024925      1.16151     1172.76  1009.69         0.0                   1.0  ...    0.0         1.0             0.0          1.0  0.183948   0.183832
# 2024-02-06 19:45:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN       NaN        NaN
# 2024-02-06 20:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN       NaN        NaN
#
# [3 rows x 480 columns]
#                        AIR_MV  AIR_DENSITY  AIR_RHO_CP   AIR_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  W_ITC  W_ITC_TEST  WBOOST_APPLIED  WPL_APPLIED        ZL  ZL_UNCORR
# TIMESTAMP_MIDDLE                                                                                   ...
# 2026-03-31 23:45:00  0.023961      1.20871     1215.82  1005.88         0.0                   1.0  ...   44.0         3.0             0.0          1.0 -0.246235  -0.220565
# 2026-04-01 00:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...    NaN         NaN             NaN          NaN       NaN        NaN
# 2026-04-01 00:45:00  0.023944      1.20915     1220.27  1009.20         0.0                   1.0  ...   63.0         4.0             0.0          1.0  0.031237   0.033957
#
# [3 rows x 480 columns]
#                              FC
# STARTDATE      2024-02-06 19:15
# ENDDATE        2026-04-01 00:45
# PERIOD        784 days 05:30:00
# NOV                       15985
# MISSING                   21659
# MISSING_PERC          57.536394
# MEAN                  -1.040635
# MEDIAN                -0.387283
# SD                    31.306925
# VAR                  980.123533
# SD/MEAN              -30.084455
# SUM               -16634.543879
# MIN                    -2094.52
# MAX                     759.037
# P01                  -74.193932
# P05                   -18.22158
# P25                    -4.94721
# P75                     2.70396
# P95                    16.90994
# P99                   67.478636

# %%
# [print(c) for c in maindf if "VPD" in c]

# %%
# TimeSeries(series=maindf[FLUXVAR]).plot_interactive()
TimeSeries(series=maindf[FLUXVAR]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # START FLUX PROCESSING CHAIN

# %% [markdown]
# - First we need to initialize the processing chain by providing some basic info.
# - At the same time, some fundamental variables are also created: potential radiation, and two flags based on it: daytime flag (1=daytime) and nighttime flag (1=nighttime).

# %%
fpc = FluxProcessingChain(
    df=maindf,
    fluxcol=FLUXVAR,
    site_lat=SITE_LAT,
    site_lon=SITE_LON,
    utc_offset=UTC_OFFSET,    
    nighttime_threshold=NIGHTTIME_THRESHOLD,
    daytime_accept_qcf_below=DAYTIME_ACCEPT_QCF_BELOW,
    nighttimetime_accept_qcf_below=NIGHTTIMETIME_ACCEPT_QCF_BELOW
)
# Out:
# Detected base variable CO2 for FC. (CO2 was used to calculate FC.)
# Calculated potential radiation from latitude and longitude (SW_IN_POT) ...
# Calculated daytime flag DAYTIME and nighttime flag NIGHTTIME from SW_IN_POT ...
# ++ Added new column SW_IN_POT to input data.  (!) Existing SW_IN_POT in input data is overwritten.
# ++ Added new column DAYTIME to input data.
# ++ Added new column NIGHTTIME to input data.

# %% [markdown]
# - Let's check the flux processing chain dataframe: this are the data the chain is working with in this run:

# %%
fpc.fpc_df
# Out:
#                            FC     USTAR  SW_IN_POT  DAYTIME  NIGHTTIME
# TIMESTAMP_MIDDLE
# 2024-02-06 19:15:00  2.603330  0.166264        0.0      0.0        1.0
# 2024-02-06 19:45:00       NaN       NaN        0.0      0.0        1.0
# 2024-02-06 20:15:00       NaN       NaN        0.0      0.0        1.0
# 2024-02-06 20:45:00       NaN       NaN        0.0      0.0        1.0
# 2024-02-06 21:15:00       NaN       NaN        0.0      0.0        1.0
# ...                       ...       ...        ...      ...        ...
# 2026-03-31 22:45:00       NaN       NaN        0.0      0.0        1.0
# 2026-03-31 23:15:00       NaN       NaN        0.0      0.0        1.0
# 2026-03-31 23:45:00 -0.440650  0.086584        0.0      0.0        1.0
# 2026-04-01 00:15:00       NaN       NaN        0.0      0.0        1.0
# 2026-04-01 00:45:00  0.159401  0.091593        0.0      0.0        1.0
#
# [37644 rows x 5 columns]

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟡Level-2: QUALITY FLAG EXTENSION

# %% [markdown]
# > Extract additional quality information from the EddyPro output and store it in newly added quality flags.
#
#
#
# Note that the USTAR filtering is not part of the Level-2 calculations.

# %% [markdown]
# </br>

# %% [markdown]
# ## User settings
# - A test for missing values is always included: flag calculated here from missing flux values in the EddyPro output file

# %% [markdown]
# </br>

# %% [markdown]
# ### SSITC tests (default: `True`)
# - Flag calculated in EddyPro
# - Combination of the two partial tests *steady state test* and *developed turbulent conditions test*
# - This notebook expects the SSITC flag to follow the flagging policy according to Mauder and Foken 2004:
#     - `0` for best quality fluxes
#     - `1` for fluxes suitable for general analysis such as annual budgets (although this is debatable for nighttime data)
#     - `2` for fluxes that should be discarded from the dataset
# - `TEST_SSITC_SETFLAG_TIMEPERIOD` can be used to specify time periods when the flag is set to given value, allowing for stricter SSITC filtering during certain time periods.
#     - For example: Set flag 1 to value 2 between '2022-05-01' and '2023-09-30', and between '2024-04-02' and '2024-04-19' (dates inclusive):
#                     `TEST_SSITC_SETFLAG_TIMEPERIOD = {2: [ [1, '2022-05-01', '2023-09-30'], [1, '2024-04-02', '2024-04-19'] ]}`

# %%
TEST_SSITC = True  # True or False (default: True)
TEST_SSITC_SETFLAG_TIMEPERIOD = None
# TEST_SSITC_SETFLAG_TIMEPERIOD = {2: [[1, '2022-05-01', '2023-09-30']]}

# %% [markdown]
# </br>

# %% [markdown]
# ### Flux base variable completeness test (default: `True`)
# - Flag newly calculated here
# - Check completeness of the variable that was used to calculate the respective flux
# - Example: `CO2` is the base variable that was used to calculate flux `FC`, the test is therefore run on `CO2`
# - Checks number of records of the relevant base variable available for each averaging Interval and calculates completeness flag as follows:
#     - `0` for files where >= 99% of base variable are available
#     - `1` for files where >= 97% and < 99% of base variable are available
#     - `2` for files where < 97% of base variable are available
#
# List of flux base variables and the corresponding fluxes:
# - `CO2`: used to calculate `FC`
# - `H2O`: used to calculate `FH2O`
# - `H2O`: used to calculate `LE`
# - `H2O`: used to calculate `ET`
# - `T_SONIC`: used to calculate `H`
# - `N2O`: used to calculate `FN2O`
# - `CH4`: used to calculate `FCH4`

# %%
TEST_GAS_COMPLETENESS = False  # True or False (default: True)

# %% [markdown]
# </br>

# %% [markdown]
# ### Spectral correction factor test (default: `True`)
# - Flag calculated here from the gas `SCF` variable in EddyPro output file

# %%
TEST_SPECTRAL_CORRECTION_FACTOR = True  # True or False (default: True)

# %% [markdown]
# </br>

# %% [markdown]
# ### Signal strength test

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Always recommended if flux was calculated using a gas analyzer.</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Do not use for H (sensible heat flux).</b> This test is only relevant for fluxes where the concentration/temperature was measured by a gas analyzer, e.g. FC, FH2O, LE, ET, N2O, CH4, etc ...
# </div>

# %% [markdown]
# - Signal strength / AGC / window dirtiness test (if available)
# - Flag calculated here from the signal strength / AGC variable for the gas analyzer in EddyPro output file.
# - The original info for this flag comes from the IRGA diagnostics. If the flag was already considered during EddyPro processing (bad values already filtered out) then this flag does probably not need to be considered here.
# - `SIGNAL_STRENGTH_COL`: Name of the column storing the signal strength, e.g. `CUSTOM_AGC_MEAN` for LI-7500, `CUSTOM_SIGNAL_STRENGTH_IRGA72_MEAN` for LI-7200, or something similar.
# - `SIGNAL_STRENGTH_THRESHOLD`: Signal strength threshold, flux values where threshold is exceeded are flagged as rejected.
# - `SIGNAL_STRENGTH_METHOD`: `discard above` flags fluxes where signal strength > threshold, `discard below` where signal strength < threshold. FOr IRGAs such as LI-7200 high signal strength values mean good signal, low values bad signal. For the open-path IRGA LI-7500 it is the opposite: high values bad signal, low values good signal.

# %%
# Signal strength
TEST_SIGNAL_STRENGTH = True  # True or False (default: True)
TEST_SIGNAL_STRENGTH_COL = 'CUSTOM_AGC_MEAN'  # Variable name in fluxnet files
TEST_SIGNAL_STRENGTH_METHOD = 'discard above'  # 'discard above' or 'discard below'
TEST_SIGNAL_STRENGTH_THRESHOLD = 90

# %%
# TimeSeries(series=df_orig[SIGNAL_STRENGTH_COL]).plot_interactive()
TimeSeries(series=maindf[TEST_SIGNAL_STRENGTH_COL]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# ### Raw data screening tests
# - Flags were calculated in EddyPro
# - See here for more details: [Despiking and raw data statistical screening (EddyPro help)](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html)

# %%
TEST_RAWDATA = True  # Default True
TEST_RAWDATA_SPIKES = True  # Default True
TEST_RAWDATA_AMPLITUDE = False  # Default True
TEST_RAWDATA_DROPOUT = True  # Default True
TEST_RAWDATA_ABSLIM = False  # Default False
TEST_RAWDATA_SKEWKURT_HF = False  # Default False
TEST_RAWDATA_SKEWKURT_SF = False  # Default False
TEST_RAWDATA_DISCONT_HF = False  # Default False
TEST_RAWDATA_DISCONT_SF = False  # Default False

# %% [markdown]
# </br>

# %% [markdown]
# ### Angle-of-attack test (default: `False`)
# > This test calculates sample-wise Angle of Attacks throughout the current flux averaging period, and flags it if the percentage of angles of attack exceeding a user-defined range is beyond a (user-defined) threshold.
# > Source: [EddyPro help](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html?Highlight=angle%20of%20attack#Angleofattack)  *(3 Jan 2024)*
# - Flag was calculated in EddyPro
# - Flag can be useful during some time periods when the sonic anemometer had issues
# - Not used by default (similar to ICOS)

# %%
TEST_RAWDATA_ANGLE_OF_ATTACK = False  # Default False
TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES = []
# TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES = [['2008-01-01', '2010-01-01'],
#                                                   ['2016-03-01', '2016-05-01']]

# %% [markdown]
# </br>

# %% [markdown]
# ### Steadiness of horizontal wind test (default: `False`)
# > This test assesses whether the along-wind and crosswind components of the wind vector undergo a systematic reduction (or increase) throughout the file. If the quadratic combination of such systematic variations is beyond the user-selected limit, the flux averaging period is hard-flagged for instationary horizontal wind (Vickers and Mahrt, 1997, Par. 6g).
# > Source: [EddyPro help](https://www.licor.com/env/support/EddyPro/topics/despiking-raw-statistical-screening.html?Highlight=angle%20of%20attack#Steadinessofhorizontalwind)  *(3 Jan 2024)*
# - Flag was calculated in EddyPro

# %%
TEST_RAWDATA_STEADINESS_OF_HORIZONTAL_WIND = False  # Default False

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Run

# %%
LEVEL2_SETTINGS = {
    'signal_strength': {
        'apply': TEST_SIGNAL_STRENGTH,
        'signal_strength_col': TEST_SIGNAL_STRENGTH_COL,
        'method': TEST_SIGNAL_STRENGTH_METHOD,
        'threshold': TEST_SIGNAL_STRENGTH_THRESHOLD},
    'raw_data_screening_vm97': {
        'apply': TEST_RAWDATA,
        'spikes': TEST_RAWDATA_SPIKES,
        'amplitude': TEST_RAWDATA_AMPLITUDE,
        'dropout': TEST_RAWDATA_DROPOUT,
        'abslim': TEST_RAWDATA_ABSLIM,
        'skewkurt_hf': TEST_RAWDATA_SKEWKURT_HF,
        'skewkurt_sf': TEST_RAWDATA_SKEWKURT_SF,
        'discont_hf': TEST_RAWDATA_DISCONT_HF,
        'discont_sf': TEST_RAWDATA_DISCONT_SF},
    'ssitc': {
        'apply': TEST_SSITC,
        'setflag_timeperiod': TEST_SSITC_SETFLAG_TIMEPERIOD},
    'gas_completeness': {
        'apply': TEST_GAS_COMPLETENESS},
    'spectral_correction_factor': {
        'apply': TEST_SPECTRAL_CORRECTION_FACTOR},
    'angle_of_attack': {
        'apply': TEST_RAWDATA_ANGLE_OF_ATTACK,
        'application_dates': TEST_RAWDATA_ANGLE_OF_ATTACK_APPLICATION_DATES},
    'steadiness_of_horizontal_wind': {
        'apply': TEST_RAWDATA_STEADINESS_OF_HORIZONTAL_WIND}
}
fpc.level2_quality_flag_expansion(**LEVEL2_SETTINGS)
# Out:
# [MissingValues]  running MissingValues ...
# SSITC TEST: Generated new flag variable FLAG_L2_FC_SSITC_TEST, values taken from output variable FC_SSITC_TEST ...
# SPECTRAL CORRECTION FACTOR TEST: Generating new flag variable FLAG_L2_FC_SCF_TEST, newly calculated from output variable FC_SCF, withflag 0 (good values) where FC_SCF < 2, flag 1 (ok values) where FC_SCF >= 2 and < 4, flag 2 (bad values) where FC_SCF >= 4...
# SIGNAL STRENGTH TEST: Generating new flag variable FLAG_L2_FC_SIGNAL_STRENGTH_TEST, newly calculated from output variable CUSTOM_AGC_MEAN, with flag 0 (good values) where CUSTOM_AGC_MEAN <= 90, flag 2 (bad values) where CUSTOM_AGC_MEAN > 90 ...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST, values taken from output variable CO2_VM97_TEST from position 1, based on CO2, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...
# RAW DATA TEST: Generated new flag variable FLAG_L2_FC_CO2_VM97_DROPOUT_TEST, values taken from output variable CO2_VM97_TEST from position 3, based on CO2, with flag 0 (good values) where test passed, flag 2 (bad values) where test failed (for hard flags) or flag 1 (ok values) where test failed (for soft flags) ...

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Finalize Level-2

# %%
fpc.finalize_level2()
# Out:
# ++Added new column FLAG_L2_FC_MISSING_TEST.
# ++Added new column FLAG_L2_FC_SSITC_TEST.
# ++Added new column FLAG_L2_FC_SCF_TEST.
# ++Added new column FLAG_L2_FC_SIGNAL_STRENGTH_TEST.
# ++Added new column FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST.
# ++Added new column FLAG_L2_FC_CO2_VM97_DROPOUT_TEST.
# ++Added new column SUM_L2_FC_HARDFLAGS.
# ++Added new column SUM_L2_FC_SOFTFLAGS.
# ++Added new column SUM_L2_FC_FLAGS.
# ++Added new column FLAG_L2_FC_QCF.
# ++Added new column FC_L2_QCF.
# ++Added new column FC_L2_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-2` variables
# - This shows all available Level-2 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L2' in x]
# Out:
# ['FLAG_L2_FC_MISSING_TEST',
#  'FLAG_L2_FC_SSITC_TEST',
#  'FLAG_L2_FC_SCF_TEST',
#  'FLAG_L2_FC_SIGNAL_STRENGTH_TEST',
#  'FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST',
#  'FLAG_L2_FC_CO2_VM97_DROPOUT_TEST',
#  'SUM_L2_FC_HARDFLAGS',
#  'SUM_L2_FC_SOFTFLAGS',
#  'SUM_L2_FC_FLAGS',
#  'FLAG_L2_FC_QCF',
#  'FC_L2_QCF',
#  'FC_L2_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plots

# %%
fpc.level2_qcf.showplot_qcf_heatmaps()

# %%
# fpc.level2_qcf.showplot_qcf_timeseries()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
fpc.level2_qcf.report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable FC.
#
# Number of FC records before QC: 15985
# +++ FLAG_L2_FC_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 15985 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FC_SSITC_TEST rejected 2013 values (+12.59%)      TOTALS: flag 0: 7144 (44.69%) / flag 1: 6828 (42.72%) / flag 2: 2013 (12.59%)
# +++ FLAG_L2_FC_SCF_TEST rejected 7 values (+0.04%)      TOTALS: flag 0: 7132 (44.62%) / flag 1: 6833 (42.75%) / flag 2: 2020 (12.64%)
# +++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST rejected 855 values (+5.35%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
#
# In total, 2875 (17.99%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2

# %%
fpc.level2_qcf.report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L2_FC_QCF, QCF FLAG FOR FC
# ========================================
# Between 2024-02-06 19:15 and 2026-04-01 00:45 ...
#     Total flux records BEFORE quality checks: 15985 (42.46% of potential)
#     Available flux records AFTER quality checks: 13110 (82.01% of total)
#     Rejected flux records: 2875 (17.99% of total)
#     Potential flux records: 37644
#     Potential flux records missed: 21659 (57.54% of potential)

# %%
# fpc.level2_qcf.report_qcf_flags()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🔵Level-3.1: STORAGE CORRECTION

# %% [markdown]
# - The flux storage term (single point) is added to the flux
# - For some records, the storage term can be missing. In such cases, missing terms are gap-filled using the rolling mean in an expanding window.
# - Without gap-filling the storage term, we can lose an additional e.g. 2-3% of flux data

# %% [markdown]
# </br>

# %% [markdown]
# ## Run

# %%
fpc.level31_storage_correction(gapfill_storage_term=True)
# Out:
# Detected storage variable SC_SINGLE for FC.
# Calculating storage-corrected flux NEE_L3.1 from flux FC and storage term SC_SINGLE ...
# Missing values for storage term SC_SINGLE_gfRMED_L3.1: 358
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 5 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 341 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 7 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 204 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 9 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 175 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 11 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 141 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 13 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 122 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 15 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 111 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 17 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 95 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 19 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 81 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 21 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 71 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 23 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 61 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 25 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 49 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 27 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 42 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 29 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 38 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 31 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 33 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 33 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 28 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 35 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 26 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 37 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 22 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 39 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 20 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 41 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 19 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 43 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 16 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 45 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 14 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 47 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 13 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 49 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 10 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 51 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 7 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 57 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 6 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 61 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 5 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 63 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 4 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 65 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 2 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 83 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 1 ...
# Gap-filling storage-term SC_SINGLE with rolling median (window size = 93 records, centered)  |  still missing values for storage term SC_SINGLE_gfRMED_L3.1: 0 ...

# %% [markdown]
# </br>

# %% [markdown]
# ## Finalize Level-3.1

# %%
fpc.finalize_level31()
# Out:
# ++Added new column SC_SINGLE.
# ++Added new column SC_SINGLE_gfRMED_L3.1.
# ++Added new column FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED.
# ++Added new column NEE_L3.1.
# ++Added new column NEE_L3.1_QCF (Level-3.1 with applied quality flag from Level-2).
# ++Added new column NEE_L3.1_QCF0 (Level-3.1 with applied quality flag from Level-2).

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.1` variables
# - This shows all available Level-3.1 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.1' in x]
# Out:
# ['SC_SINGLE_gfRMED_L3.1',
#  'FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED',
#  'NEE_L3.1',
#  'NEE_L3.1_QCF',
#  'NEE_L3.1_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plots

# %%
fpc.level31.showplot()

# %% [markdown]
# </br>

# %% [markdown]
# ### Report

# %%
fpc.level31.report()
# Out:
# ========================================
# REPORT: STORAGE CORRECTION FOR FC
# ========================================
# Swiss FluxNet processing chain, _L3.1: Storage Correction
#
# The gap-filled storage term SC_SINGLE_gfRMED_L3.1 was added to flux FC.
# The storage-corrected flux was stored as NEE_L3.1.
#
# The flux was available for 15985 records (FC).
# The original, non-gapfilled storage term was available for 15627 records (SC_SINGLE).
# The original storage term SC_SINGLE was missing for 358 flux records.
# Without gap-filling the storage term (SC_SINGLE), 358 measured flux records (FC) are lost.
#
# For this run, gap-filling of SC_SINGLE was * SELECTED *.
# After gap-filling the storage term, it was available for an additional 358 records (SC_SINGLE_gfRMED_L3.1).
#
# In the storage-corrected flux NEE_L3.1 with 15985 records,
#   - 97.8% (15627 records) of used storage terms come from originally calculated data (SC_SINGLE)
#   - 2.2% (358 records) of used storage terms come from gap-filled data (SC_SINGLE_gfRMED_L3.1)
#
# Stats for gap-filled storage terms:
#                        NOV      P01    MEDIAN      P99
# SC_SINGLE_gfRMED_L3.1  358 -12.9102 -0.011582  10.3305
#
# Stats for measured storage terms:
#                          NOV       P01    MEDIAN       P99
# SC_SINGLE_gfRMED_L3.1  15627 -9.569542 -0.037819  7.678483

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ANALYZE HIGHEST-QUALITY FLUX (optional)

# %% [markdown]
# - Analysis of fluxes after Level-3.1 where the overall quality flag `QCF` = 0
# - This helps in understanding in what range the "true" flux occurs
# - Here, the highest-quality fluxes are additionally filtered for outlier values using the relatively fast Local Outlier Factor test
# - For this quick analysis, it is possible that the outlier test cuts off some "real" values that should be retained, but it nevertheless helps in understanding the flux range
# - `QCF` = 0 is best quality, `QCF` = medium quality, `QCF` = 2 bad quality and always rejected
# - The difference between quality 0 and quality 1 or 2 is huge

# %%
analyze_highest_quality_flux(flux=fpc.fpc_df[fpc.filteredseries_hq.name], nighttime_flag=fpc.fpc_df['NIGHTTIME'])
# Out:
# >>> Removing outliers from highest-quality DAYTIME fluxes (NEE_L3.1_QCF0)
# >>> Outlier removal method: Local outlier factor across all data (n_neighbors=25, contamination=auto, repeat=False)
# [LocalOutlierFactorAllData]  running LocalOutlierFactorAllData ...
# Detecting time resolution from timestamp TIMESTAMP_MIDDLE ... OK
#    Detected 30min time resolution with HIGH confidence.
#    Resolution detected from most frequent timestep (timedelta):
#        from full data = None / -failed- (not used)
#        from timedelta = 30min / 96% occurrence (OK)
#        from progressive = 30min / data 19+19 (not used)
#
# ITERATION#1: Total found outliers: 28 values (daytime+nighttime)
# >>> Largest non-outlier flux >= 0 DAYTIME:   40.035145
# >>> Smallest non-outlier flux >= 0 DAYTIME:  0.0020550000000000013
# >>> Largest non-outlier flux < 0 DAYTIME:    -0.003670000000000506
# >>> Smallest non-outlier flux < 0 DAYTIME:   -38.463499999999996
# >>> Largest outlier flux >= 0 DAYTIME:   90.07624
# >>> Smallest outlier flux >= 0 DAYTIME:  43.494730000000004
# >>> Largest outlier flux < 0 DAYTIME:    -40.015049999999995
# >>> Smallest outlier flux < 0 DAYTIME:   -151.06984
#
# >>> Removing outliers from highest-quality NIGHTTIME fluxes (NEE_L3.1_QCF0)
# >>> Outlier removal method: Local outlier factor across all data (n_neighbors=9, contamination=auto, repeat=False)
# [LocalOutlierFactorAllData]  running LocalOutlierFactorAllData ...
# Detecting time resolution from timestamp TIMESTAMP_MIDDLE ... OK
#    Detected 30min time resolution with HIGH confidence.
#    Resolution detected from most frequent timestep (timedelta):
#        from full data = None / -failed- (not used)
#        from timedelta = 30min / 96% occurrence (OK)
#        from progressive = 30min / data 13+13 (not used)
#
# ITERATION#1: Total found outliers: 23 values (daytime+nighttime)
# >>> Largest non-outlier flux >= 0 NIGHTTIME:   33.931142
# >>> Smallest non-outlier flux >= 0 NIGHTTIME:  0.03820000000000001
# >>> Largest non-outlier flux < 0 NIGHTTIME:    -0.0008088799999999997
# >>> Smallest non-outlier flux < 0 NIGHTTIME:   -93.35957
# >>> Largest outlier flux >= 0 NIGHTTIME:   80.40486
# >>> Smallest outlier flux >= 0 NIGHTTIME:  1.8016910000000002
# >>> Largest outlier flux < 0 NIGHTTIME:    -23.208005
# >>> Smallest outlier flux < 0 NIGHTTIME:   -161.1897

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🔴Level-3.2: OUTLIER DETECTION

# %% [markdown]
# - Running an outlier test creates a *preview* plot of the results
# - If the output looks as desired, run `fpc.level32_addflag()` cell below the preview to accept the results you see in the plot
# - All subsequent tests will then be based on these results
# - This means that each test is run on the data already filtered by the previous test
# - Each test creates its own quality flag
# - At the end of Level-3.2, an overall quality flag `QCF` is created that combines all of the individual flags into one single flag

# %% [markdown]
# </br>

# %% [markdown]
# ## Plot time series

# %%
print(f"{fpc.filteredseries.name} \n(quality-controlled Level-3.1 version of {fpc.fluxcol})")
# Out:
# NEE_L3.1_QCF
# (quality-controlled Level-3.1 version of FC)

# %%
# TimeSeries(series=fpc.fpc_df[fpc.filteredseries.name]).plot_interactive()
TimeSeries(series=fpc.fpc_df[fpc.filteredseries.name]).plot()

# %% [markdown]
# </br>

# %% [markdown]
# ## Initiate calculations

# %%
fpc.level32_stepwise_outlier_detection()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Absolute limits
# - remove values outside a physically plausible range
# - typical value for CO2 flux `FC`: +/-50 µmol m-2 s-1
# - typical value for latent evaporation flux `LE`: +800 / -50 W m-2
# - typical value for sensible heat flux `H`: +400 / -200 W m-2

# %%
# from diive.pkgs.outlierdetection.absolutelimits import AbsoluteLimits
# help(AbsoluteLimits)

# %%
# MIN = -50
# MAX = 50
# fpc.level32_flag_outliers_abslim_test(minval=MIN, maxval=MAX, showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Manual removal
# - The interactive plot can be used to determine the exact start and end of time ranges or data points that need to be removed, e.g. due to known instrument failure

# %%
# from diive.pkgs.outlierdetection.manualremoval import ManualRemoval
# help(ManualRemoval)

# %%
# # fpc.level32.showplot_cleaned(interactive=True)  # True or False
# fpc.level32.showplot_cleaned(interactive=False)  # True or False

# %%
# REMOVE_DATES = [
#     ['2022-03-18 12:15:00', '2022-04-03 06:45:00'],  # Removes date range between two datetimes (inclusive)
#     # '2023-12-12 12:45:00'  # Removes data point with specific timestamp
# ]
# fpc.level32_flag_manualremoval_test(
#     remove_dates=REMOVE_DATES,
#     showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %%
# fpc.level32.showplot_cleaned(interactive=True)  # True or False

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Hampel filter (daytime/nighttime)
# - Recommended filter

# %%
# from diive.pkgs.outlierdetection.hampel import HampelDaytimeNighttime
# help(HampelDaytimeNighttime)
# print(HampelDaytimeNighttime.__init__.__doc__)

# %%
# %%time
WINDOW_LENGTH = 48 * 13
N_SIGMA_DT = 5.5
N_SIGMA_NT = 5.5
USE_DIFFERENCING = True
SEPARATE_DAY_NIGHT = True
fpc.level32_flag_outliers_hampel_dtnt_test(window_length=WINDOW_LENGTH, n_sigma_dt=N_SIGMA_DT, n_sigma_nt=N_SIGMA_NT, use_differencing=USE_DIFFERENCING, separate_day_night=SEPARATE_DAY_NIGHT,
                                           showplot=True, verbose=True, repeat=True)
# Out:
# [HampelDaytimeNighttime]  running HampelDaytimeNighttime ...
# [Dt/Nt] ITER #01 | Outliers:   964 (  7.35%) | Day:   614 | Night:   350
# [Dt/Nt] ITER #02 | Outliers:   190 (  1.56%) | Day:   109 | Night:    81
# [Dt/Nt] ITER #03 | Outliers:    37 (  0.31%) | Day:    24 | Night:    13
# [Dt/Nt] ITER #04 | Outliers:    10 (  0.08%) | Day:     5 | Night:     5
# [Dt/Nt] ITER #05 | Outliers:     2 (  0.02%) | Day:     2 | Night:     0
# [Dt/Nt] ITER #06 | Outliers:     2 (  0.02%) | Day:     1 | Night:     1
# [Dt/Nt] ITER #07 | Outliers:     0 (  0.00%) | Day:     0 | Night:     0
# CPU times: total: 1.56 s
# Wall time: 1.56 s

# %%
fpc.level32_addflag()
# Out:
# ++Added flag column FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST to flag data

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Local standard deviation (daytime/nighttime)
# - keep standard deviation constant by setting parameter `constant_sd=True`

# %%
# N_SD = [3.5, 3.5]
# WINSIZE = [48 * 3, 48 * 3]
# fpc.level32_flag_outliers_localsd_test(
#     n_sd=N_SD, winsize=WINSIZE, constant_sd=False,
#     separate_daytime_nighttime=True, showplot=True, verbose=True, repeat=False
# )

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## z-score (all data)

# %%
# from diive.pkgs.outlierdetection.zscore import zScore
# help(zScore)

# %%
# THRES_ZSCORE = 6
# fpc.level32_flag_outliers_zscore_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## z-score (daytime/nighttime)

# %%
# from diive.pkgs.outlierdetection.zscore import zScoreDaytimeNighttime
# help(zScoreDaytimeNighttime)

# %%
# THRES_ZSCORE = 6
# fpc.level32_flag_outliers_zscore_dtnt_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## z-score (rolling, all data)

# %%
# from diive.pkgs.outlierdetection.zscore import zScoreRolling
# help(zScoreRolling)

# %%
# THRES_ZSCORE = 5.5
# WINSIZE = 48 * 13
# fpc.level32_flag_outliers_zscore_rolling_test(winsize=WINSIZE, thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Local standard deviation (rolling SD)

# %%
# from diive.pkgs.outlierdetection.localsd import LocalSD
# help(LocalSD)

# %%
# N_SD = 4.5
# WINSIZE = 48 * 9
# fpc.level32_flag_outliers_localsd_test(n_sd=N_SD, winsize=WINSIZE, constant_sd=False, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Local standard deviation (constant SD)
# - keep standard deviation constant by setting parameter `constant_sd=True`

# %%
# N_SD = 4.5
# WINSIZE = 48 * 9
# fpc.level32_flag_outliers_localsd_test(n_sd=N_SD, winsize=WINSIZE, constant_sd=True, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Increments z-score (all data)

# %%
# from diive.pkgs.outlierdetection.incremental import zScoreIncrements
# help(zScoreIncrements)

# %%
# THRES_ZSCORE = 4
# fpc.level32_flag_outliers_increments_zcore_test(thres_zscore=THRES_ZSCORE, showplot=True, verbose=True, repeat=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Local outlier factor (daytime/nighttime)
# - Test is run separately for daytime and nighttime data
# - Description of local outlier factor: [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
# from diive.pkgs.outlierdetection.lof import LocalOutlierFactorDaytimeNighttime
# help(LocalOutlierFactorDaytimeNighttime)

# %%
# N_NEIGHBORS = 100
# CONTAMINATION = None
# fpc.level32_flag_outliers_lof_dtnt_test(n_neighbors=N_NEIGHBORS, contamination=CONTAMINATION, showplot=True, verbose=True, repeat=False, n_jobs=-1)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Local outlier factor (all data)
# - Test is run across all data
# - Description of local outlier factor: [here](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html)

# %%
# from diive.pkgs.outlierdetection.lof import LocalOutlierFactorAllData
# help(LocalOutlierFactorAllData)

# %%
# N_NEIGHBORS = 24
# CONTAMINATION = None
# fpc.level32_flag_outliers_lof_test(n_neighbors=N_NEIGHBORS, contamination=CONTAMINATION, showplot=True, verbose=True, repeat=False, n_jobs=-1)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Absolute limits (daytime/nighttime)

# %%
# from diive.pkgs.outlierdetection.absolutelimits import AbsoluteLimitsDaytimeNighttime
# help(AbsoluteLimitsDaytimeNighttime)

# %%
# MIN_DT = -50
# MAX_DT = 50
# MIN_NT = -25
# MAX_NT = 25
# fpc.level32_flag_outliers_abslim_dtnt_test(daytime_minmax=[MIN_DT, MAX_DT], nighttime_minmax=[MIN_NT, MAX_NT], showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Trim nighttime flux data

# %%
# from diive.pkgs.outlierdetection.trim import TrimLow
# help(TrimLow)

# %%
# fpc.level32_flag_outliers_trim_low_test(trim_nighttime=True, lower_limit=-5, showplot=True, verbose=True)

# %%
# fpc.level32_addflag()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Finalize Level-3.2: Calculate overall quality flag (so far)

# %%
fpc.finalize_level32()
# Out:
# ++Added new column FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST.
# ++Added new column SUM_L3.2_NEE_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.2_NEE_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.2_NEE_L3.1_FLAGS.
# ++Added new column FLAG_L3.2_NEE_L3.1_QCF.
# ++Added new column NEE_L3.1_L3.2_QCF.
# ++Added new column NEE_L3.1_L3.2_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# ### Available `Level-3.2` variables
# - This shows all available Level-3.2 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.2' in x]
# Out:
# ['FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST',
#  'SUM_L3.2_NEE_L3.1_HARDFLAGS',
#  'SUM_L3.2_NEE_L3.1_SOFTFLAGS',
#  'SUM_L3.2_NEE_L3.1_FLAGS',
#  'FLAG_L3.2_NEE_L3.1_QCF',
#  'NEE_L3.1_L3.2_QCF',
#  'NEE_L3.1_L3.2_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ### Plot filtered flux after Level-3.2
# In the four panels, from left to right:
# - flux after Level-3.1, before outlier removal
# - flux after Level-3.2, after outlier removal
# - sum of the individual test flags
# - overall flag `QCF` (quality control flag), where `0`=best quality, `1`=medium quality, `2`=bad quality

# %%
fpc.level32_qcf.showplot_qcf_heatmaps()

# %%
TimeSeries(series=fpc.filteredseries).plot()
# TimeSeries(series=fpc.filteredseries).plot_interactive()

# %%
# fpc.level32_qcf.showplot_qcf_timeseries()

# %% [markdown]
# </br>

# %% [markdown]
# ### Reports

# %%
fpc.level32_qcf.report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable NEE_L3.1.
#
# Number of NEE_L3.1 records before QC: 15985
# +++ FLAG_L2_FC_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 15985 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FC_SSITC_TEST rejected 2013 values (+12.59%)      TOTALS: flag 0: 7144 (44.69%) / flag 1: 6828 (42.72%) / flag 2: 2013 (12.59%)
# +++ FLAG_L2_FC_SCF_TEST rejected 7 values (+0.04%)      TOTALS: flag 0: 7132 (44.62%) / flag 1: 6833 (42.75%) / flag 2: 2020 (12.64%)
# +++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST rejected 855 values (+5.35%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST rejected 1205 values (+7.54%)      TOTALS: flag 0: 6680 (41.79%) / flag 1: 5225 (32.69%) / flag 2: 4080 (25.52%)
#
# In total, 4080 (25.52%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2

# %%
fpc.level32_qcf.report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L3.2_NEE_L3.1_QCF, QCF FLAG FOR NEE_L3.1
# ========================================
# Between 2024-02-06 19:15 and 2026-04-01 00:45 ...
#     Total flux records BEFORE quality checks: 15985 (42.46% of potential)
#     Available flux records AFTER quality checks: 11905 (74.48% of total)
#     Rejected flux records: 4080 (25.52% of total)
#     Potential flux records: 37644
#     Potential flux records missed: 21659 (57.54% of potential)

# %%
fpc.level32_qcf.report_qcf_flags()
# Out:
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 15985 values (42.46%)
#     OVERALL flag 2.0: 21659 values (57.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10224 values (55.60%)
#     DAYTIME flag 2.0: 8165 values (44.40%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5761 values (29.92%)
#     NIGHTTIME flag 2.0: 13494 values (70.08%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 7144 values (18.98%)
#     OVERALL flag 1.0: 6828 values (18.14%)
#     OVERALL flag 2.0: 2013 values (5.35%)
#     OVERALL flag missing: 21659 values (57.54%)
#
#     DAYTIME flag 0.0: 5208 values (28.32%)
#     DAYTIME flag 1.0: 3942 values (21.44%)
#     DAYTIME flag 2.0: 1074 values (5.84%)
#     DAYTIME flag missing: 8165 values (44.40%)
#
#     NIGHTTIME flag 0.0: 1936 values (10.05%)
#     NIGHTTIME flag 1.0: 2886 values (14.99%)
#     NIGHTTIME flag 2.0: 939 values (4.88%)
#     NIGHTTIME flag missing: 13494 values (70.08%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 15827 values (42.04%)
#     OVERALL flag 1.0: 127 values (0.34%)
#     OVERALL flag 2.0: 31 values (0.08%)
#     OVERALL flag missing: 21659 values (57.54%)
#
#     DAYTIME flag 0.0: 10186 values (55.39%)
#     DAYTIME flag 1.0: 32 values (0.17%)
#     DAYTIME flag 2.0: 6 values (0.03%)
#     DAYTIME flag missing: 8165 values (44.40%)
#
#     NIGHTTIME flag 0.0: 5641 values (29.30%)
#     NIGHTTIME flag 1.0: 95 values (0.49%)
#     NIGHTTIME flag 2.0: 25 values (0.13%)
#     NIGHTTIME flag missing: 13494 values (70.08%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 15721 values (41.76%)
#     OVERALL flag 2.0: 1459 values (3.88%)
#     OVERALL flag missing: 20464 values (54.36%)
#
#     DAYTIME flag 0.0: 10267 values (55.83%)
#     DAYTIME flag 2.0: 550 values (2.99%)
#     DAYTIME flag missing: 7572 values (41.18%)
#
#     NIGHTTIME flag 0.0: 5454 values (28.33%)
#     NIGHTTIME flag 2.0: 909 values (4.72%)
#     NIGHTTIME flag missing: 12892 values (66.95%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 17252 values (45.83%)
#     OVERALL flag 2.0: 3 values (0.01%)
#     OVERALL flag missing: 20389 values (54.16%)
#
#     DAYTIME flag 0.0: 10848 values (58.99%)
#     DAYTIME flag 2.0: 2 values (0.01%)
#     DAYTIME flag missing: 7539 values (41.00%)
#
#     NIGHTTIME flag 0.0: 6404 values (33.26%)
#     NIGHTTIME flag 2.0: 1 values (0.01%)
#     NIGHTTIME flag missing: 12850 values (66.74%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 17255 values (45.84%)
#     OVERALL flag missing: 20389 values (54.16%)
#
#     DAYTIME flag 0.0: 10850 values (59.00%)
#     DAYTIME flag missing: 7539 values (41.00%)
#
#     NIGHTTIME flag 0.0: 6405 values (33.26%)
#     NIGHTTIME flag missing: 12850 values (66.74%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 6975 values (18.53%)
#     OVERALL flag 1.0: 6135 values (16.30%)
#     OVERALL flag 2.0: 24534 values (65.17%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 5144 values (27.97%)
#     DAYTIME flag 1.0: 3693 values (20.08%)
#     DAYTIME flag 2.0: 9552 values (51.94%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1831 values (9.51%)
#     NIGHTTIME flag 1.0: 2442 values (12.68%)
#     NIGHTTIME flag 2.0: 14982 values (77.81%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 36439 values (96.80%)
#     OVERALL flag 2.0: 1205 values (3.20%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 17634 values (95.89%)
#     DAYTIME flag 2.0: 755 values (4.11%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 18805 values (97.66%)
#     NIGHTTIME flag 2.0: 450 values (2.34%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 6680 values (17.75%)
#     OVERALL flag 1.0: 5225 values (13.88%)
#     OVERALL flag 2.0: 25739 values (68.37%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 4945 values (26.89%)
#     DAYTIME flag 1.0: 3137 values (17.06%)
#     DAYTIME flag 2.0: 10307 values (56.05%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1735 values (9.01%)
#     NIGHTTIME flag 1.0: 2088 values (10.84%)
#     NIGHTTIME flag 2.0: 15432 values (80.15%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 15985 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10224 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5761 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 7144 values (44.69%)
#     OVERALL flag 1.0: 6828 values (42.72%)
#     OVERALL flag 2.0: 2013 values (12.59%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 5208 values (50.94%)
#     DAYTIME flag 1.0: 3942 values (38.56%)
#     DAYTIME flag 2.0: 1074 values (10.50%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1936 values (33.61%)
#     NIGHTTIME flag 1.0: 2886 values (50.10%)
#     NIGHTTIME flag 2.0: 939 values (16.30%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 15827 values (99.01%)
#     OVERALL flag 1.0: 127 values (0.79%)
#     OVERALL flag 2.0: 31 values (0.19%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10186 values (99.63%)
#     DAYTIME flag 1.0: 32 values (0.31%)
#     DAYTIME flag 2.0: 6 values (0.06%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5641 values (97.92%)
#     NIGHTTIME flag 1.0: 95 values (1.65%)
#     NIGHTTIME flag 2.0: 25 values (0.43%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 14809 values (92.64%)
#     OVERALL flag 2.0: 1176 values (7.36%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 9799 values (95.84%)
#     DAYTIME flag 2.0: 425 values (4.16%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5010 values (86.96%)
#     NIGHTTIME flag 2.0: 751 values (13.04%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 15982 values (99.98%)
#     OVERALL flag 2.0: 3 values (0.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10222 values (99.98%)
#     DAYTIME flag 2.0: 2 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5760 values (99.98%)
#     NIGHTTIME flag 2.0: 1 values (0.02%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 15985 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10224 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5761 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 6975 values (43.63%)
#     OVERALL flag 1.0: 6135 values (38.38%)
#     OVERALL flag 2.0: 2875 values (17.99%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 5144 values (50.31%)
#     DAYTIME flag 1.0: 3693 values (36.12%)
#     DAYTIME flag 2.0: 1387 values (13.57%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1831 values (31.78%)
#     NIGHTTIME flag 1.0: 2442 values (42.39%)
#     NIGHTTIME flag 2.0: 1488 values (25.83%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 14780 values (92.46%)
#     OVERALL flag 2.0: 1205 values (7.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 9469 values (92.62%)
#     DAYTIME flag 2.0: 755 values (7.38%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5311 values (92.19%)
#     NIGHTTIME flag 2.0: 450 values (7.81%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 6680 values (41.79%)
#     OVERALL flag 1.0: 5225 values (32.69%)
#     OVERALL flag 2.0: 4080 values (25.52%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 4945 values (48.37%)
#     DAYTIME flag 1.0: 3137 values (30.68%)
#     DAYTIME flag 2.0: 2142 values (20.95%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1735 values (30.12%)
#     NIGHTTIME flag 1.0: 2088 values (36.24%)
#     NIGHTTIME flag 2.0: 1938 values (33.64%)
#     NIGHTTIME flag missing: 0 values (0.00%)

# %% [markdown]
# </br>

# %% [markdown]
# ## Save Level-3.2 results to file
# - If needed, save results so far (input data and all created variables, e.g. flags and filtered fluxes) to a file
# - This can be useful if e.g. USTAR filtering is not needed and gap-filling is done elsewhere (ReddyProc...)

# %%
# results_df = fpc.get_data()
# filename = "51.1_FluxProcessingChain_after-L3.3_NEE"
# results_df.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=results_df, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟠Level-3.3: USTAR FILTERING

# %% [markdown]
# - Daytime and nighttime data are filtered based on USTAR thresholds
# - Example USTAR thresholds from the analysis done by FLUXNET (2005-2023) for the intensively managed grassland [CH-CHA, Chamau](https://www.swissfluxnet.ethz.ch/index.php/sites/site-info-ch-cha/):
#     - CUT_16: `0.0529445`
#     - CUT_50: `0.0698982`
#     - CUT_84: `0.0928408`

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     No USTAR filtering for: <b>H, LE, ET and FH2O.</b>
# </div>

# %% [markdown]
# > The USTAR filtering is not applied to H and LE, because it has not been proved that when there are CO2 advective fluxes, these also impact energy fluxes, specifically due to the fact that when advection is in general large (nighttime), energy fluxes are small.
#
# source: [Pastorello et al. (2020). The FLUXNET2015 dataset and the ONEFlux processing pipeline for eddy covariance data](https://doi.org/10.1038/s41597-020-0534-3)

# %% [markdown]
# ## Apply constant thresholds

# %%
USTAR_SCENARIOS = ['CUT_50']
USTAR_THRESHOLDS = [0.09]
# USTAR_SCENARIOS = ['CUT_16', 'CUT_50', 'CUT_84']
# USTAR_THRESHOLDS = [0.271619922, 0.303628125, 0.339684084]  # CH-LAE
fpc.level33_constant_ustar(thresholds=USTAR_THRESHOLDS,
                           threshold_labels=USTAR_SCENARIOS,
                           showplot=False)
# Out:
# [FlagSingleConstantUstarThreshold]  running FlagSingleConstantUstarThreshold ...
# Total found outliers for USTAR threshold _L3.3_CUT_50 0.09: 3622 values

# %% [markdown]
# ## Calculate overall quality control flag `QCF`

# %%
# Finalize: stores results for each USTAR scenario in a dict
fpc.finalize_level33()
# Out:
# Calculating overall quality flag QCF for USTAR scenario CUT_50...
# ++Added new column FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST.
# ++Added new column SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS.
# ++Added new column SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS.
# ++Added new column SUM_L3.3_CUT_50_NEE_L3.1_FLAGS.
# ++Added new column FLAG_L3.3_CUT_50_NEE_L3.1_QCF.
# ++Added new column NEE_L3.1_L3.3_CUT_50_QCF.
# ++Added new column NEE_L3.1_L3.3_CUT_50_QCF0.

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟡OVERVIEW: DATA AFTER `Level-3.3`

# %% [markdown]
# ## Available `Level-3.3` variables
# - This shows all available Level-3.3 variables for this flux

# %%
[x for x in fpc.fpc_df.columns if 'L3.3' in x]
# Out:
# ['FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST',
#  'SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS',
#  'SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS',
#  'SUM_L3.3_CUT_50_NEE_L3.1_FLAGS',
#  'FLAG_L3.3_CUT_50_NEE_L3.1_QCF',
#  'NEE_L3.1_L3.3_CUT_50_QCF',
#  'NEE_L3.1_L3.3_CUT_50_QCF0']

# %% [markdown]
# </br>

# %% [markdown]
# ## Plot filtered flux after Level-3.3
# In the four panels, from left to right:
# - flux after Level-3.1, before outlier removal and USTAR filtering
# - flux after Level-3.3, after outlier removal and USTAR filtering
# - sum of the individual test flags
# - overall flag `QCF` (quality control flag), where `0`=best quality, `1`=medium quality, `2`=bad quality

# %%
for key, value in fpc.level33_qcf.items():
    # TimeSeries(series=fpc.fpc_df[fluxhq]).plot_interactive()
    # TimeSeries(series=fpc.fpc_df[FLUXVAR33QCF[key].name]).plot()
    fpc.level33_qcf[key].showplot_qcf_heatmaps()

# %% [markdown]
# </br>

# %% [markdown]
# ## Reports

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_evolution()
# Out:
# ========================================
# QCF FLAG EVOLUTION
# ========================================
# This output shows the evolution of the QCF overall quality flag
# when test flags are applied sequentially to the variable NEE_L3.1.
#
# Number of NEE_L3.1 records before QC: 15985
# +++ FLAG_L2_FC_MISSING_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 15985 (100.00%) / flag 1: 0 (0.00%) / flag 2: 0 (0.00%)
# +++ FLAG_L2_FC_SSITC_TEST rejected 2013 values (+12.59%)      TOTALS: flag 0: 7144 (44.69%) / flag 1: 6828 (42.72%) / flag 2: 2013 (12.59%)
# +++ FLAG_L2_FC_SCF_TEST rejected 7 values (+0.04%)      TOTALS: flag 0: 7132 (44.62%) / flag 1: 6833 (42.75%) / flag 2: 2020 (12.64%)
# +++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST rejected 855 values (+5.35%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST rejected 0 values (+0.00%)      TOTALS: flag 0: 6975 (43.63%) / flag 1: 6135 (38.38%) / flag 2: 2875 (17.99%)
# +++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST rejected 1205 values (+7.54%)      TOTALS: flag 0: 6680 (41.79%) / flag 1: 5225 (32.69%) / flag 2: 4080 (25.52%)
# +++ FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST rejected 2213 values (+13.84%)      TOTALS: flag 0: 6001 (37.54%) / flag 1: 3691 (23.09%) / flag 2: 6293 (39.37%)
#
# In total, 6293 (39.37%) of the available records were rejected in this step.
# INFO Rejected DAYTIME records where QCF flag >= 2
# INFO Rejected NIGHTTIME records where QCF flag >= 2

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_series()
# Out:
# ========================================
# SUMMARY: FLAG_L3.3_CUT_50_NEE_L3.1_QCF, QCF FLAG FOR NEE_L3.1
# ========================================
# Between 2024-02-06 19:15 and 2026-04-01 00:45 ...
#     Total flux records BEFORE quality checks: 15985 (42.46% of potential)
#     Available flux records AFTER quality checks: 9692 (60.63% of total)
#     Rejected flux records: 6293 (39.37% of total)
#     Potential flux records: 37644
#     Potential flux records missed: 21659 (57.54% of potential)

# %%
for key, value in fpc.level33_qcf.items():
    fpc.level33_qcf[key].report_qcf_flags()
# Out:
# ========================================
# REPORT: FLAGS INCL. MISSING VALUES
# ========================================
# Stats with missing values in the dataset
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 15985 values (42.46%)
#     OVERALL flag 2.0: 21659 values (57.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10224 values (55.60%)
#     DAYTIME flag 2.0: 8165 values (44.40%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5761 values (29.92%)
#     NIGHTTIME flag 2.0: 13494 values (70.08%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 7144 values (18.98%)
#     OVERALL flag 1.0: 6828 values (18.14%)
#     OVERALL flag 2.0: 2013 values (5.35%)
#     OVERALL flag missing: 21659 values (57.54%)
#
#     DAYTIME flag 0.0: 5208 values (28.32%)
#     DAYTIME flag 1.0: 3942 values (21.44%)
#     DAYTIME flag 2.0: 1074 values (5.84%)
#     DAYTIME flag missing: 8165 values (44.40%)
#
#     NIGHTTIME flag 0.0: 1936 values (10.05%)
#     NIGHTTIME flag 1.0: 2886 values (14.99%)
#     NIGHTTIME flag 2.0: 939 values (4.88%)
#     NIGHTTIME flag missing: 13494 values (70.08%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 15827 values (42.04%)
#     OVERALL flag 1.0: 127 values (0.34%)
#     OVERALL flag 2.0: 31 values (0.08%)
#     OVERALL flag missing: 21659 values (57.54%)
#
#     DAYTIME flag 0.0: 10186 values (55.39%)
#     DAYTIME flag 1.0: 32 values (0.17%)
#     DAYTIME flag 2.0: 6 values (0.03%)
#     DAYTIME flag missing: 8165 values (44.40%)
#
#     NIGHTTIME flag 0.0: 5641 values (29.30%)
#     NIGHTTIME flag 1.0: 95 values (0.49%)
#     NIGHTTIME flag 2.0: 25 values (0.13%)
#     NIGHTTIME flag missing: 13494 values (70.08%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 15721 values (41.76%)
#     OVERALL flag 2.0: 1459 values (3.88%)
#     OVERALL flag missing: 20464 values (54.36%)
#
#     DAYTIME flag 0.0: 10267 values (55.83%)
#     DAYTIME flag 2.0: 550 values (2.99%)
#     DAYTIME flag missing: 7572 values (41.18%)
#
#     NIGHTTIME flag 0.0: 5454 values (28.33%)
#     NIGHTTIME flag 2.0: 909 values (4.72%)
#     NIGHTTIME flag missing: 12892 values (66.95%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 17252 values (45.83%)
#     OVERALL flag 2.0: 3 values (0.01%)
#     OVERALL flag missing: 20389 values (54.16%)
#
#     DAYTIME flag 0.0: 10848 values (58.99%)
#     DAYTIME flag 2.0: 2 values (0.01%)
#     DAYTIME flag missing: 7539 values (41.00%)
#
#     NIGHTTIME flag 0.0: 6404 values (33.26%)
#     NIGHTTIME flag 2.0: 1 values (0.01%)
#     NIGHTTIME flag missing: 12850 values (66.74%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 17255 values (45.84%)
#     OVERALL flag missing: 20389 values (54.16%)
#
#     DAYTIME flag 0.0: 10850 values (59.00%)
#     DAYTIME flag missing: 7539 values (41.00%)
#
#     NIGHTTIME flag 0.0: 6405 values (33.26%)
#     NIGHTTIME flag missing: 12850 values (66.74%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 6975 values (18.53%)
#     OVERALL flag 1.0: 6135 values (16.30%)
#     OVERALL flag 2.0: 24534 values (65.17%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 5144 values (27.97%)
#     DAYTIME flag 1.0: 3693 values (20.08%)
#     DAYTIME flag 2.0: 9552 values (51.94%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1831 values (9.51%)
#     NIGHTTIME flag 1.0: 2442 values (12.68%)
#     NIGHTTIME flag 2.0: 14982 values (77.81%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 36439 values (96.80%)
#     OVERALL flag 2.0: 1205 values (3.20%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 17634 values (95.89%)
#     DAYTIME flag 2.0: 755 values (4.11%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 18805 values (97.66%)
#     NIGHTTIME flag 2.0: 450 values (2.34%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 6680 values (17.75%)
#     OVERALL flag 1.0: 5225 values (13.88%)
#     OVERALL flag 2.0: 25739 values (68.37%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 4945 values (26.89%)
#     DAYTIME flag 1.0: 3137 values (17.06%)
#     DAYTIME flag 2.0: 10307 values (56.05%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1735 values (9.01%)
#     NIGHTTIME flag 1.0: 2088 values (10.84%)
#     NIGHTTIME flag 2.0: 15432 values (80.15%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 34022 values (90.38%)
#     OVERALL flag 2.0: 3622 values (9.62%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 17112 values (93.06%)
#     DAYTIME flag 2.0: 1277 values (6.94%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 16910 values (87.82%)
#     NIGHTTIME flag 2.0: 2345 values (12.18%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 6001 values (15.94%)
#     OVERALL flag 1.0: 3691 values (9.81%)
#     OVERALL flag 2.0: 27952 values (74.25%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 4722 values (25.68%)
#     DAYTIME flag 1.0: 2592 values (14.10%)
#     DAYTIME flag 2.0: 11075 values (60.23%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1279 values (6.64%)
#     NIGHTTIME flag 1.0: 1099 values (5.71%)
#     NIGHTTIME flag 2.0: 16877 values (87.65%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
#
# ========================================
# REPORT: FLAGS FOR AVAILABLE RECORDS
# ========================================
# Stats after removal of missing values
# FLAG_L2_FC_MISSING_TEST:
#     OVERALL flag 0.0: 15985 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10224 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5761 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SSITC_TEST:
#     OVERALL flag 0.0: 7144 values (44.69%)
#     OVERALL flag 1.0: 6828 values (42.72%)
#     OVERALL flag 2.0: 2013 values (12.59%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 5208 values (50.94%)
#     DAYTIME flag 1.0: 3942 values (38.56%)
#     DAYTIME flag 2.0: 1074 values (10.50%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1936 values (33.61%)
#     NIGHTTIME flag 1.0: 2886 values (50.10%)
#     NIGHTTIME flag 2.0: 939 values (16.30%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SCF_TEST:
#     OVERALL flag 0.0: 15827 values (99.01%)
#     OVERALL flag 1.0: 127 values (0.79%)
#     OVERALL flag 2.0: 31 values (0.19%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10186 values (99.63%)
#     DAYTIME flag 1.0: 32 values (0.31%)
#     DAYTIME flag 2.0: 6 values (0.06%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5641 values (97.92%)
#     NIGHTTIME flag 1.0: 95 values (1.65%)
#     NIGHTTIME flag 2.0: 25 values (0.43%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_SIGNAL_STRENGTH_TEST:
#     OVERALL flag 0.0: 14809 values (92.64%)
#     OVERALL flag 2.0: 1176 values (7.36%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 9799 values (95.84%)
#     DAYTIME flag 2.0: 425 values (4.16%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5010 values (86.96%)
#     NIGHTTIME flag 2.0: 751 values (13.04%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST:
#     OVERALL flag 0.0: 15982 values (99.98%)
#     OVERALL flag 2.0: 3 values (0.02%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10222 values (99.98%)
#     DAYTIME flag 2.0: 2 values (0.02%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5760 values (99.98%)
#     NIGHTTIME flag 2.0: 1 values (0.02%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_CO2_VM97_DROPOUT_TEST:
#     OVERALL flag 0.0: 15985 values (100.00%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 10224 values (100.00%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5761 values (100.00%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L2_FC_QCF:
#     OVERALL flag 0.0: 6975 values (43.63%)
#     OVERALL flag 1.0: 6135 values (38.38%)
#     OVERALL flag 2.0: 2875 values (17.99%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 5144 values (50.31%)
#     DAYTIME flag 1.0: 3693 values (36.12%)
#     DAYTIME flag 2.0: 1387 values (13.57%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1831 values (31.78%)
#     NIGHTTIME flag 1.0: 2442 values (42.39%)
#     NIGHTTIME flag 2.0: 1488 values (25.83%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST:
#     OVERALL flag 0.0: 14780 values (92.46%)
#     OVERALL flag 2.0: 1205 values (7.54%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 9469 values (92.62%)
#     DAYTIME flag 2.0: 755 values (7.38%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 5311 values (92.19%)
#     NIGHTTIME flag 2.0: 450 values (7.81%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.2_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 6680 values (41.79%)
#     OVERALL flag 1.0: 5225 values (32.69%)
#     OVERALL flag 2.0: 4080 values (25.52%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 4945 values (48.37%)
#     DAYTIME flag 1.0: 3137 values (30.68%)
#     DAYTIME flag 2.0: 2142 values (20.95%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1735 values (30.12%)
#     NIGHTTIME flag 1.0: 2088 values (36.24%)
#     NIGHTTIME flag 2.0: 1938 values (33.64%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST:
#     OVERALL flag 0.0: 12629 values (79.01%)
#     OVERALL flag 2.0: 3356 values (20.99%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 9036 values (88.38%)
#     DAYTIME flag 2.0: 1188 values (11.62%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 3593 values (62.37%)
#     NIGHTTIME flag 2.0: 2168 values (37.63%)
#     NIGHTTIME flag missing: 0 values (0.00%)
#
# FLAG_L3.3_CUT_50_NEE_L3.1_QCF:
#     OVERALL flag 0.0: 6001 values (37.54%)
#     OVERALL flag 1.0: 3691 values (23.09%)
#     OVERALL flag 2.0: 6293 values (39.37%)
#     OVERALL flag missing: 0 values (0.00%)
#
#     DAYTIME flag 0.0: 4722 values (46.19%)
#     DAYTIME flag 1.0: 2592 values (25.35%)
#     DAYTIME flag 2.0: 2910 values (28.46%)
#     DAYTIME flag missing: 0 values (0.00%)
#
#     NIGHTTIME flag 0.0: 1279 values (22.20%)
#     NIGHTTIME flag 1.0: 1099 values (19.08%)
#     NIGHTTIME flag 2.0: 3383 values (58.72%)
#     NIGHTTIME flag missing: 0 values (0.00%)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Flux variable names

# %%
fluxes_qcf = [c for c in fpc.fpc_df.columns if str(c).endswith("_QCF") and not str(c).startswith("FLAG_") and "L3.3" in c]
fluxes_qcf0 = [c for c in fpc.fpc_df.columns if
               str(c).endswith("_QCF0") and not str(c).startswith("FLAG_") and "L3.3" in c]
print(f"Quality-controlled fluxes: {fluxes_qcf}")
print(f"Quality-controlled fluxes, HIGHEST QUALITY: {fluxes_qcf0}")
if (DAYTIME_ACCEPT_QCF_BELOW == 1) & (NIGHTTIMETIME_ACCEPT_QCF_BELOW == 1):
    print(f"{'*' * 100}\nNote that since only QCF below 1 is accepted for daytime and nighttime data, "
          f"the _QCF and _QCF0 variables are identical.")
# Out:
# Quality-controlled fluxes: ['NEE_L3.1_L3.3_CUT_50_QCF']
# Quality-controlled fluxes, HIGHEST QUALITY: ['NEE_L3.1_L3.3_CUT_50_QCF0']

# %% [markdown]
# </br>

# %%
FLUXVAR2QCF = fpc.filteredseries_level2_qcf.name
FLUXVAR31QCF = fpc.filteredseries_level31_qcf.name
FLUXVAR32QCF = fpc.filteredseries_level32_qcf.name
FLUXVAR32QCF_HQ = f"{FLUXVAR32QCF}0"
FLUXVAR33QCF = fpc.filteredseries_level33_qcf

print("--------------------------")
print("OVERVIEW OF FLUX VARIABLES")
print("--------------------------")
print(
    f""
    f"{FLUXVAR} ... original input flux\n"
    f"{FLUXVAR2QCF} ... flux quality-controlled with Level-2 flags\n    -->  not used in any further processing steps\n"
    f"{FLUXVAR31QCF} ... flux quality-controlled with Level-2 flags, including Level-3.1 storage correction\n   -->  not used in any further processing steps\n"
    f"{FLUXVAR32QCF} ... flux quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)\n    -->  not used in any further processing steps\n"
    f"{FLUXVAR32QCF_HQ} ... highest-quality flux (QCF=0), quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)\n    -->  not used in any further processing steps\n"
)
print("Variables for further steps:")
for key, value in FLUXVAR33QCF.items():
    print(
        f"{FLUXVAR33QCF[key].name} ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering ({key}), including Level-3.1 storage correction\n-->   to be used in gap-filling and all further steps")

if (DAYTIME_ACCEPT_QCF_BELOW == 1) & (NIGHTTIMETIME_ACCEPT_QCF_BELOW == 1):
    print(f"{'*' * 100}\nNote that since only QCF below 1 is accepted for daytime and nighttime data, "
          f"the _QCF and _QCF0 variables are identical.")
# Out:
# --------------------------
# OVERVIEW OF FLUX VARIABLES
# --------------------------
# FC ... original input flux
# FC_L2_QCF ... flux quality-controlled with Level-2 flags
#     -->  not used in any further processing steps
# NEE_L3.1_QCF ... flux quality-controlled with Level-2 flags, including Level-3.1 storage correction
#    -->  not used in any further processing steps
# NEE_L3.1_L3.2_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)
#     -->  not used in any further processing steps
# NEE_L3.1_L3.2_QCF0 ... highest-quality flux (QCF=0), quality-controlled with Level-2 and Level-3.2 flags, including Level-3.1 storage correction)
#     -->  not used in any further processing steps
#
# Variables for further steps:
# NEE_L3.1_L3.3_CUT_50_QCF ... flux quality-controlled with Level-2 and Level-3.2 flags, and after Level-3.3 USTAR filtering (CUT_50), including Level-3.1 storage correction
# -->   to be used in gap-filling and all further steps

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Quality-controlled flux after `Level-3.3`
# - Plot flux after storage-correction, flux quality control, outlier removal and USTAR filtering

# %%
_fluxcols = [x for x in fpc.fpc_df.columns if 'L3.1' and 'L3.3' in x and str(x).endswith('_QCF') and not str(x).startswith('FLAG_')]
fpc.fpc_df[_fluxcols].plot(subplots=True, x_compat=True, title="Available Level-3.3 fluxes after application of all quality checks", figsize=(12, 4.5));

# %%
# Draw boxplots
_fluxcols = [x for x in fpc.fpc_df.columns if 'L3.1' and 'L3.3' in x and str(x).endswith('_QCF') and not str(x).startswith('FLAG_')]
for _f in _fluxcols:
    boxplots_df = fpc.fpc_df[[_f, "DAYTIME"]].copy()
    boxplots_df["MONTH"] = boxplots_df.index.month
    # sns.set_theme(style="ticks", palette="pastel")
    plt.figure(figsize=(8, 5), dpi=72)
    sns.boxplot(x="MONTH", y=_f, palette=["r", "b"], hue="DAYTIME", data=boxplots_df).set_title(f"Boxplot of {_f}")
    sns.despine(offset=10, trim=True)
    plt.axhline(0, color="black");

# %% [markdown]
# ## Cumulatives of Level data (not-gap-filled)

# %%
# Creating a dictionary by passing Series objects as values
frame = {
    f'original ({FLUXVAR})': fpc.fpc_df[FLUXVAR],
    f'+ flux quality flags ({FLUXVAR2QCF})': fpc.fpc_df[FLUXVAR2QCF],
    f'++ storage correction ({FLUXVAR31QCF})': fpc.fpc_df[FLUXVAR31QCF],
    f'+++ outlier removal ({FLUXVAR32QCF})': fpc.fpc_df[FLUXVAR32QCF]
}
for key, value in FLUXVAR33QCF.items():
    frame[f'+++ USTAR filtering ({key}, {FLUXVAR33QCF[key].name})'] = FLUXVAR33QCF[key]

overview = pd.DataFrame(frame)
overview.cumsum().plot(title=f"Cumulative", figsize=(14, 7), x_compat=True, alpha=1);

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# ## Save Level-3.3 results to file (optional)
# - If needed, save results so far (input data and all created variables, e.g. flags and filtered fluxes) to a file
# - This can be useful if e.g. gap-filling should be done elsewhere (ReddyProc...)

# %%
# results_df = fpc.get_data()
# filename = "51.1_FluxProcessingChain_after-L3.3_NEE"
# results_df.to_csv(f"{filename}.csv", index=True)
# save_parquet(data=results_df, filename=filename)

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # 🟢Level-4.1: GAP-FILLING

# %% [markdown]
# - Introduced in `diive` v0.85.0, gap-filling can now be done using both random forest and MDS
# - For gap-filling using MDS, make sure that variables are in the required units: short-wave incoming radiation in `W m-2`, air temperature in `°C`, VPD in `hPa`
#
# Parameters:
# - `mds_settings` are parameters for the MDS gap-filling method, [see docstring here for more details](https://github.com/holukas/diive/blob/main/diive/pkgs/gapfilling/mds.py)
# - `rf_settings` are parameters for scikit's `RandomForestRegressor` model, [see their official documentation for allowed parameters](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
# - `ml_feature_settings` are general settings for machine-learning models (such as random forest)

# %% [markdown]
# ## 🔸Long-term random forest

# %%
# FEATURES = ["TA_EP", "SW_IN_POT", "VPD_EP"]

# # Level-4.1: Random Forest Gap-Filling with Feature Engineering (v0.91.0)
# fpc.level41_longterm_random_forest(
#     features=FEATURES,
#     # Feature Engineering Parameters
#     features_lag=[-1, 1],
#     features_lag_stepsize=1,
#     features_lag_exclude_cols=None,
#     features_rolling=[12, 24],
#     features_rolling_exclude_cols=None,
#     features_rolling_stats=['median', 'min', 'max'],
#     features_diff=[1],
#     features_diff_exclude_cols=None,
#     features_ema=[6, 24],  # NEW in v0.91.0: Exponential Moving Average features
#     features_ema_exclude_cols=None,  # NEW in v0.91.0
#     features_poly_degree=2,
#     features_poly_exclude_cols=None,
#     features_stl=False,
#     features_stl_method='stl',
#     features_stl_seasonal_period=None,
#     features_stl_exclude_cols=None,
#     features_stl_components=None,
#     vectorize_timestamps=True,
#     add_continuous_record_number=True,
#     sanitize_timestamp=True,
#     # Gap-Filling Parameters
#     reduce_features=False,
#     verbose=True,
#     # Random Forest Hyperparameters
#     n_estimators=100,
#     max_depth=15,
#     min_samples_split=5,
#     min_samples_leaf=2,
#     n_jobs=-1,
#     random_state=42,
# )

# %% [markdown]
# ## 🔸Long-term XGBoost

# %%
FEATURES = ["TA_EP", "SW_IN_POT", "VPD_EP"]

# Level-4.1: XGBoost Gap-Filling with Feature Engineering (v0.91.0, optional alternative)
fpc.level41_longterm_xgboost(
    features=FEATURES,
    # Feature Engineering Parameters (same as Random Forest for fair comparison)
    features_lag=[-1, 1],
    features_lag_stepsize=1,
    features_lag_exclude_cols=None,
    features_rolling=[12, 24, 48],
    features_rolling_exclude_cols=None,
    features_rolling_stats=['median', 'min', 'max'],
    features_diff=[1, 2],
    features_diff_exclude_cols=None,
    features_ema=[6, 12, 24],
    features_ema_exclude_cols=None,
    features_poly_degree=2,
    features_poly_exclude_cols=None,
    features_stl=False,
    features_stl_method='stl',
    features_stl_seasonal_period=None,
    features_stl_exclude_cols=None,
    features_stl_components=None,
    vectorize_timestamps=True,
    add_continuous_record_number=True,
    sanitize_timestamp=True,
    # Gap-Filling Parameters
    reduce_features=False,
    verbose=True,
    # XGBoost Hyperparameters
    n_estimators=3000,
    max_depth=6,
    learning_rate=0.05,
    early_stopping_rounds=100,
    n_jobs=-1,
    random_state=42,
)

# Access results: fpc.level41['long_term_xgboost']['CUT_50']
# Out:
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK']
# ++ Added new column .RECORDNUMBER with record numbers from 1 to 37644.
# [neighboring_years] Assigned [2024, 2025, 2026] to data pool for 2024.
# [neighboring_years] Assigned [2024, 2025, 2026] to data pool for 2025.
# [neighboring_years] Assigned [2024, 2025, 2026] to data pool for 2026.
# Initializing model for 2024 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'xgboost.sklearn.XGBRegressor'>
# ============================================================
# (!)Some features are incomplete and have less than 37644 values:
#     --> TA_EP (17255 values)
#     --> VPD_EP (15237 values)
#     --> .TA_EP-1 (17254 values)
#     --> .TA_EP+1 (17254 values)
#     --> .VPD_EP-1 (15236 values)
#     --> .VPD_EP+1 (15236 values)
#     --> .TA_EP_MEAN12 (30780 values)
#     --> .VPD_EP_MEAN12 (28839 values)
#     --> .TA_EP_SD12 (30780 values)
#     --> .VPD_EP_SD12 (28839 values)
#     --> .TA_EP_MEAN24 (35370 values)
#     --> .VPD_EP_MEAN24 (34013 values)
#     --> .TA_EP_SD24 (35370 values)
#     --> .VPD_EP_SD24 (34013 values)
#     --> .TA_EP_MEAN48 (37294 values)
#     --> .VPD_EP_MEAN48 (36674 values)
#     --> .TA_EP_SD48 (37294 values)
#     --> .VPD_EP_SD48 (36674 values)
#     --> .TA_EP_ROLLMEDIAN12 (30780 values)
#     --> .VPD_EP_ROLLMEDIAN12 (28839 values)
#     --> .TA_EP_ROLLMIN12 (30780 values)
#     --> .VPD_EP_ROLLMIN12 (28839 values)
#     --> .TA_EP_ROLLMAX12 (30780 values)
#     --> .VPD_EP_ROLLMAX12 (28839 values)
#     --> .TA_EP_ROLLMEDIAN24 (35370 values)
#     --> .VPD_EP_ROLLMEDIAN24 (34013 values)
#     --> .TA_EP_ROLLMIN24 (35370 values)
#     --> .VPD_EP_ROLLMIN24 (34013 values)
#     --> .TA_EP_ROLLMAX24 (35370 values)
#     --> .VPD_EP_ROLLMAX24 (34013 values)
#     --> .TA_EP_ROLLMEDIAN48 (37294 values)
#     --> .VPD_EP_ROLLMEDIAN48 (36674 values)
#     --> .TA_EP_ROLLMIN48 (37294 values)
#     --> .VPD_EP_ROLLMIN48 (36674 values)
#     --> .TA_EP_ROLLMAX48 (37294 values)
#     --> .VPD_EP_ROLLMAX48 (36674 values)
#     --> .TA_EP_DIFF1 (14044 values)
#     --> .SW_IN_POT_DIFF1 (37643 values)
#     --> .VPD_EP_DIFF1 (12196 values)
#     --> .TA_EP_DIFF2 (12165 values)
#     --> .SW_IN_POT_DIFF2 (37642 values)
#     --> .VPD_EP_DIFF2 (10437 values)
#     --> .TA_EP_POL2 (17255 values)
#     --> .VPD_EP_POL2 (15237 values)
# This means that not all target values can be predicted based on the full model.
# Initializing model for 2025 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'xgboost.sklearn.XGBRegressor'>
# ============================================================
# (!)Some features are incomplete and have less than 37644 values:
#     --> TA_EP (17255 values)
#     --> VPD_EP (15237 values)
#     --> .TA_EP-1 (17254 values)
#     --> .TA_EP+1 (17254 values)
#     --> .VPD_EP-1 (15236 values)
#     --> .VPD_EP+1 (15236 values)
#     --> .TA_EP_MEAN12 (30780 values)
#     --> .VPD_EP_MEAN12 (28839 values)
#     --> .TA_EP_SD12 (30780 values)
#     --> .VPD_EP_SD12 (28839 values)
#     --> .TA_EP_MEAN24 (35370 values)
#     --> .VPD_EP_MEAN24 (34013 values)
#     --> .TA_EP_SD24 (35370 values)
#     --> .VPD_EP_SD24 (34013 values)
#     --> .TA_EP_MEAN48 (37294 values)
#     --> .VPD_EP_MEAN48 (36674 values)
#     --> .TA_EP_SD48 (37294 values)
#     --> .VPD_EP_SD48 (36674 values)
#     --> .TA_EP_ROLLMEDIAN12 (30780 values)
#     --> .VPD_EP_ROLLMEDIAN12 (28839 values)
#     --> .TA_EP_ROLLMIN12 (30780 values)
#     --> .VPD_EP_ROLLMIN12 (28839 values)
#     --> .TA_EP_ROLLMAX12 (30780 values)
#     --> .VPD_EP_ROLLMAX12 (28839 values)
#     --> .TA_EP_ROLLMEDIAN24 (35370 values)
#     --> .VPD_EP_ROLLMEDIAN24 (34013 values)
#     --> .TA_EP_ROLLMIN24 (35370 values)
#     --> .VPD_EP_ROLLMIN24 (34013 values)
#     --> .TA_EP_ROLLMAX24 (35370 values)
#     --> .VPD_EP_ROLLMAX24 (34013 values)
#     --> .TA_EP_ROLLMEDIAN48 (37294 values)
#     --> .VPD_EP_ROLLMEDIAN48 (36674 values)
#     --> .TA_EP_ROLLMIN48 (37294 values)
#     --> .VPD_EP_ROLLMIN48 (36674 values)
#     --> .TA_EP_ROLLMAX48 (37294 values)
#     --> .VPD_EP_ROLLMAX48 (36674 values)
#     --> .TA_EP_DIFF1 (14044 values)
#     --> .SW_IN_POT_DIFF1 (37643 values)
#     --> .VPD_EP_DIFF1 (12196 values)
#     --> .TA_EP_DIFF2 (12165 values)
#     --> .SW_IN_POT_DIFF2 (37642 values)
#     --> .VPD_EP_DIFF2 (10437 values)
#     --> .TA_EP_POL2 (17255 values)
#     --> .VPD_EP_POL2 (15237 values)
# This means that not all target values can be predicted based on the full model.
# Initializing model for 2026 ...
#
#
# ============================================================
# Starting gap-filling for
# NEE_L3.1_L3.3_CUT_50_QCF
# using <class 'xgboost.sklearn.XGBRegressor'>
# ============================================================
# (!)Some features are incomplete and have less than 37644 values:
#     --> TA_EP (17255 values)
#     --> VPD_EP (15237 values)
#     --> .TA_EP-1 (17254 values)
#     --> .TA_EP+1 (17254 values)
#     --> .VPD_EP-1 (15236 values)
#     --> .VPD_EP+1 (15236 values)
#     --> .TA_EP_MEAN12 (30780 values)
#     --> .VPD_EP_MEAN12 (28839 values)
#     --> .TA_EP_SD12 (30780 values)
#     --> .VPD_EP_SD12 (28839 values)
#     --> .TA_EP_MEAN24 (35370 values)
#     --> .VPD_EP_MEAN24 (34013 values)
#     --> .TA_EP_SD24 (35370 values)
#     --> .VPD_EP_SD24 (34013 values)
#     --> .TA_EP_MEAN48 (37294 values)
#     --> .VPD_EP_MEAN48 (36674 values)
#     --> .TA_EP_SD48 (37294 values)
#     --> .VPD_EP_SD48 (36674 values)
#     --> .TA_EP_ROLLMEDIAN12 (30780 values)
#     --> .VPD_EP_ROLLMEDIAN12 (28839 values)
#     --> .TA_EP_ROLLMIN12 (30780 values)
#     --> .VPD_EP_ROLLMIN12 (28839 values)
#     --> .TA_EP_ROLLMAX12 (30780 values)
#     --> .VPD_EP_ROLLMAX12 (28839 values)
#     --> .TA_EP_ROLLMEDIAN24 (35370 values)
#     --> .VPD_EP_ROLLMEDIAN24 (34013 values)
#     --> .TA_EP_ROLLMIN24 (35370 values)
#     --> .VPD_EP_ROLLMIN24 (34013 values)
#     --> .TA_EP_ROLLMAX24 (35370 values)
#     --> .VPD_EP_ROLLMAX24 (34013 values)
#     --> .TA_EP_ROLLMEDIAN48 (37294 values)
#     --> .VPD_EP_ROLLMEDIAN48 (36674 values)
#     --> .TA_EP_ROLLMIN48 (37294 values)
#     --> .VPD_EP_ROLLMIN48 (36674 values)
#     --> .TA_EP_ROLLMAX48 (37294 values)
#     --> .VPD_EP_ROLLMAX48 (36674 values)
#     --> .TA_EP_DIFF1 (14044 values)
#     --> .SW_IN_POT_DIFF1 (37643 values)
#     --> .VPD_EP_DIFF1 (12196 values)
#     --> .TA_EP_DIFF2 (12165 values)
#     --> .SW_IN_POT_DIFF2 (37642 values)
#     --> .VPD_EP_DIFF2 (10437 values)
#     --> .TA_EP_POL2 (17255 values)
#     --> .VPD_EP_POL2 (15237 values)
# This means that not all target values can be predicted based on the full model.
#
# Training model for 2024 ...
#
# Training final model ...
# >>> Training model <class 'xgboost.sklearn.XGBRegressor'> based on data between 2024-02-07 01:45:00 and 2026-03-31 13:45:00 ...
# >>> Fitting model to training data ...
# [0]	validation_0-rmse:6.91977	validation_1-rmse:7.06036
# [1]	validation_0-rmse:6.68864	validation_1-rmse:6.86066
# [2]	validation_0-rmse:6.47462	validation_1-rmse:6.67563
# [3]	validation_0-rmse:6.27436	validation_1-rmse:6.50546
# [4]	validation_0-rmse:6.08431	validation_1-rmse:6.34680
# [5]	validation_0-rmse:5.90290	validation_1-rmse:6.20199
# [6]	validation_0-rmse:5.73277	validation_1-rmse:6.06601
# [7]	validation_0-rmse:5.57425	validation_1-rmse:5.93779
# [8]	validation_0-rmse:5.42653	validation_1-rmse:5.82114
# [9]	validation_0-rmse:5.28508	validation_1-rmse:5.71205
# [10]	validation_0-rmse:5.14978	validation_1-rmse:5.60885
# [11]	validation_0-rmse:5.02471	validation_1-rmse:5.51778
# [12]	validation_0-rmse:4.90853	validation_1-rmse:5.43229
# [13]	validation_0-rmse:4.79529	validation_1-rmse:5.35036
# [14]	validation_0-rmse:4.69111	validation_1-rmse:5.27746
# [15]	validation_0-rmse:4.59309	validation_1-rmse:5.21073
# [16]	validation_0-rmse:4.49749	validation_1-rmse:5.14990
# [17]	validation_0-rmse:4.41226	validation_1-rmse:5.09532
# [18]	validation_0-rmse:4.33045	validation_1-rmse:5.04387
# [19]	validation_0-rmse:4.25056	validation_1-rmse:4.99595
# [20]	validation_0-rmse:4.17493	validation_1-rmse:4.95028
# [21]	validation_0-rmse:4.10353	validation_1-rmse:4.91174
# [22]	validation_0-rmse:4.03696	validation_1-rmse:4.87355
# [23]	validation_0-rmse:3.97414	validation_1-rmse:4.83885
# [24]	validation_0-rmse:3.91483	validation_1-rmse:4.80802
# [25]	validation_0-rmse:3.86006	validation_1-rmse:4.77855
# [26]	validation_0-rmse:3.80449	validation_1-rmse:4.75025
# [27]	validation_0-rmse:3.75206	validation_1-rmse:4.72163
# [28]	validation_0-rmse:3.70606	validation_1-rmse:4.69703
# [29]	validation_0-rmse:3.66370	validation_1-rmse:4.67642
# [30]	validation_0-rmse:3.61710	validation_1-rmse:4.65068
# [31]	validation_0-rmse:3.57423	validation_1-rmse:4.63140
# [32]	validation_0-rmse:3.53764	validation_1-rmse:4.61223
# [33]	validation_0-rmse:3.49900	validation_1-rmse:4.59279
# [34]	validation_0-rmse:3.46195	validation_1-rmse:4.57882
# [35]	validation_0-rmse:3.42978	validation_1-rmse:4.56479
# [36]	validation_0-rmse:3.39779	validation_1-rmse:4.55125
# [37]	validation_0-rmse:3.36543	validation_1-rmse:4.53481
# [38]	validation_0-rmse:3.33685	validation_1-rmse:4.52236
# [39]	validation_0-rmse:3.30595	validation_1-rmse:4.51216
# [40]	validation_0-rmse:3.28281	validation_1-rmse:4.50378
# [41]	validation_0-rmse:3.25877	validation_1-rmse:4.49761
# [42]	validation_0-rmse:3.23772	validation_1-rmse:4.48905
# [43]	validation_0-rmse:3.21522	validation_1-rmse:4.47744
# [44]	validation_0-rmse:3.19873	validation_1-rmse:4.47352
# [45]	validation_0-rmse:3.17760	validation_1-rmse:4.46791
# [46]	validation_0-rmse:3.15732	validation_1-rmse:4.46162
# [47]	validation_0-rmse:3.13626	validation_1-rmse:4.45671
# [48]	validation_0-rmse:3.11830	validation_1-rmse:4.45127
# [49]	validation_0-rmse:3.10334	validation_1-rmse:4.44934
# [50]	validation_0-rmse:3.08776	validation_1-rmse:4.44657
# [51]	validation_0-rmse:3.06977	validation_1-rmse:4.44493
# [52]	validation_0-rmse:3.05584	validation_1-rmse:4.44179
# [53]	validation_0-rmse:3.04358	validation_1-rmse:4.44121
# [54]	validation_0-rmse:3.02810	validation_1-rmse:4.43687
# [55]	validation_0-rmse:3.01088	validation_1-rmse:4.43467
# [56]	validation_0-rmse:2.99520	validation_1-rmse:4.43111
# [57]	validation_0-rmse:2.98058	validation_1-rmse:4.42929
# [58]	validation_0-rmse:2.96866	validation_1-rmse:4.42946
# [59]	validation_0-rmse:2.95150	validation_1-rmse:4.42476
# [60]	validation_0-rmse:2.93973	validation_1-rmse:4.42415
# [61]	validation_0-rmse:2.92631	validation_1-rmse:4.42180
# [62]	validation_0-rmse:2.91224	validation_1-rmse:4.41911
# [63]	validation_0-rmse:2.89797	validation_1-rmse:4.41472
# [64]	validation_0-rmse:2.88720	validation_1-rmse:4.41422
# [65]	validation_0-rmse:2.87414	validation_1-rmse:4.41303
# [66]	validation_0-rmse:2.85981	validation_1-rmse:4.40863
# [67]	validation_0-rmse:2.84807	validation_1-rmse:4.40602
# [68]	validation_0-rmse:2.83734	validation_1-rmse:4.40400
# [69]	validation_0-rmse:2.82706	validation_1-rmse:4.40073
# [70]	validation_0-rmse:2.81456	validation_1-rmse:4.40072
# [71]	validation_0-rmse:2.80121	validation_1-rmse:4.39920
# [72]	validation_0-rmse:2.79281	validation_1-rmse:4.39807
# [73]	validation_0-rmse:2.78565	validation_1-rmse:4.39658
# [74]	validation_0-rmse:2.77474	validation_1-rmse:4.39447
# [75]	validation_0-rmse:2.76679	validation_1-rmse:4.39154
# [76]	validation_0-rmse:2.75678	validation_1-rmse:4.38962
# [77]	validation_0-rmse:2.74488	validation_1-rmse:4.39060
# [78]	validation_0-rmse:2.73797	validation_1-rmse:4.38990
# [79]	validation_0-rmse:2.72608	validation_1-rmse:4.39044
# [80]	validation_0-rmse:2.72023	validation_1-rmse:4.38988
# [81]	validation_0-rmse:2.70893	validation_1-rmse:4.38815
# [82]	validation_0-rmse:2.69575	validation_1-rmse:4.38531
# [83]	validation_0-rmse:2.68973	validation_1-rmse:4.38373
# [84]	validation_0-rmse:2.67981	validation_1-rmse:4.38504
# [85]	validation_0-rmse:2.66933	validation_1-rmse:4.38349
# [86]	validation_0-rmse:2.66148	validation_1-rmse:4.38453
# [87]	validation_0-rmse:2.65618	validation_1-rmse:4.38422
# [88]	validation_0-rmse:2.64892	validation_1-rmse:4.38459
# [89]	validation_0-rmse:2.64013	validation_1-rmse:4.38229
# [90]	validation_0-rmse:2.63524	validation_1-rmse:4.38238
# [91]	validation_0-rmse:2.62223	validation_1-rmse:4.37986
# [92]	validation_0-rmse:2.61464	validation_1-rmse:4.37725
# [93]	validation_0-rmse:2.60777	validation_1-rmse:4.37544
# [94]	validation_0-rmse:2.60071	validation_1-rmse:4.37314
# [95]	validation_0-rmse:2.59250	validation_1-rmse:4.37414
# [96]	validation_0-rmse:2.58781	validation_1-rmse:4.37396
# [97]	validation_0-rmse:2.57939	validation_1-rmse:4.37281
# [98]	validation_0-rmse:2.57315	validation_1-rmse:4.37034
# [99]	validation_0-rmse:2.56429	validation_1-rmse:4.37251
# [100]	validation_0-rmse:2.56100	validation_1-rmse:4.37326
# [101]	validation_0-rmse:2.55472	validation_1-rmse:4.37038
# [102]	validation_0-rmse:2.54935	validation_1-rmse:4.36842
# [103]	validation_0-rmse:2.54470	validation_1-rmse:4.36816
# [104]	validation_0-rmse:2.54001	validation_1-rmse:4.36654
# [105]	validation_0-rmse:2.53455	validation_1-rmse:4.36628
# [106]	validation_0-rmse:2.53053	validation_1-rmse:4.36752
# [107]	validation_0-rmse:2.52571	validation_1-rmse:4.36767
# [108]	validation_0-rmse:2.52104	validation_1-rmse:4.36771
# [109]	validation_0-rmse:2.51359	validation_1-rmse:4.36911
# [110]	validation_0-rmse:2.50893	validation_1-rmse:4.36776
# [111]	validation_0-rmse:2.50520	validation_1-rmse:4.36631
# [112]	validation_0-rmse:2.50086	validation_1-rmse:4.36533
# [113]	validation_0-rmse:2.49699	validation_1-rmse:4.36537
# [114]	validation_0-rmse:2.49135	validation_1-rmse:4.36352
# [115]	validation_0-rmse:2.48346	validation_1-rmse:4.36473
# [116]	validation_0-rmse:2.47818	validation_1-rmse:4.36487
# [117]	validation_0-rmse:2.47416	validation_1-rmse:4.36479
# [118]	validation_0-rmse:2.47038	validation_1-rmse:4.36468
# [119]	validation_0-rmse:2.46609	validation_1-rmse:4.36491
# [120]	validation_0-rmse:2.46110	validation_1-rmse:4.36323
# [121]	validation_0-rmse:2.45089	validation_1-rmse:4.36564
# [122]	validation_0-rmse:2.44771	validation_1-rmse:4.36540
# [123]	validation_0-rmse:2.44428	validation_1-rmse:4.36434
# [124]	validation_0-rmse:2.44151	validation_1-rmse:4.36368
# [125]	validation_0-rmse:2.43425	validation_1-rmse:4.36247
# [126]	validation_0-rmse:2.42949	validation_1-rmse:4.36228
# [127]	validation_0-rmse:2.42534	validation_1-rmse:4.36159
# [128]	validation_0-rmse:2.42236	validation_1-rmse:4.36120
# [129]	validation_0-rmse:2.41979	validation_1-rmse:4.36082
# [130]	validation_0-rmse:2.41473	validation_1-rmse:4.35787
# [131]	validation_0-rmse:2.40699	validation_1-rmse:4.35732
# [132]	validation_0-rmse:2.40207	validation_1-rmse:4.35757
# [133]	validation_0-rmse:2.40025	validation_1-rmse:4.35704
# [134]	validation_0-rmse:2.39632	validation_1-rmse:4.35595
# [135]	validation_0-rmse:2.39253	validation_1-rmse:4.35543
# [136]	validation_0-rmse:2.38945	validation_1-rmse:4.35578
# [137]	validation_0-rmse:2.38231	validation_1-rmse:4.35504
# [138]	validation_0-rmse:2.37415	validation_1-rmse:4.35256
# [139]	validation_0-rmse:2.37081	validation_1-rmse:4.35198
# [140]	validation_0-rmse:2.36808	validation_1-rmse:4.35072
# [141]	validation_0-rmse:2.36052	validation_1-rmse:4.35027
# [142]	validation_0-rmse:2.35504	validation_1-rmse:4.35099
# [143]	validation_0-rmse:2.34846	validation_1-rmse:4.35055
# [144]	validation_0-rmse:2.34546	validation_1-rmse:4.35020
# [145]	validation_0-rmse:2.34331	validation_1-rmse:4.34964
# [146]	validation_0-rmse:2.33788	validation_1-rmse:4.34939
# [147]	validation_0-rmse:2.33485	validation_1-rmse:4.34870
# [148]	validation_0-rmse:2.33166	validation_1-rmse:4.34889
# [149]	validation_0-rmse:2.32758	validation_1-rmse:4.34780
# [150]	validation_0-rmse:2.32339	validation_1-rmse:4.34685
# [151]	validation_0-rmse:2.31956	validation_1-rmse:4.34714
# [152]	validation_0-rmse:2.31618	validation_1-rmse:4.34712
# [153]	validation_0-rmse:2.31071	validation_1-rmse:4.34642
# [154]	validation_0-rmse:2.30517	validation_1-rmse:4.34517
# [155]	validation_0-rmse:2.30288	validation_1-rmse:4.34502
# [156]	validation_0-rmse:2.29720	validation_1-rmse:4.34480
# [157]	validation_0-rmse:2.29438	validation_1-rmse:4.34461
# [158]	validation_0-rmse:2.28729	validation_1-rmse:4.34271
# [159]	validation_0-rmse:2.28478	validation_1-rmse:4.34239
# [160]	validation_0-rmse:2.28216	validation_1-rmse:4.34211
# [161]	validation_0-rmse:2.27903	validation_1-rmse:4.34023
# [162]	validation_0-rmse:2.27722	validation_1-rmse:4.33994
# [163]	validation_0-rmse:2.27448	validation_1-rmse:4.33988
# [164]	validation_0-rmse:2.26886	validation_1-rmse:4.33873
# [165]	validation_0-rmse:2.26331	validation_1-rmse:4.33878
# [166]	validation_0-rmse:2.26070	validation_1-rmse:4.33939
# [167]	validation_0-rmse:2.25707	validation_1-rmse:4.33884
# [168]	validation_0-rmse:2.25151	validation_1-rmse:4.33882
# [169]	validation_0-rmse:2.24741	validation_1-rmse:4.33878
# [170]	validation_0-rmse:2.24278	validation_1-rmse:4.33985
# [171]	validation_0-rmse:2.24026	validation_1-rmse:4.33949
# [172]	validation_0-rmse:2.23275	validation_1-rmse:4.34100
# [173]	validation_0-rmse:2.22801	validation_1-rmse:4.34091
# [174]	validation_0-rmse:2.22429	validation_1-rmse:4.34084
# [175]	validation_0-rmse:2.22033	validation_1-rmse:4.34090
# [176]	validation_0-rmse:2.21334	validation_1-rmse:4.33960
# [177]	validation_0-rmse:2.21003	validation_1-rmse:4.34035
# [178]	validation_0-rmse:2.20549	validation_1-rmse:4.34080
# [179]	validation_0-rmse:2.20291	validation_1-rmse:4.33960
# [180]	validation_0-rmse:2.19745	validation_1-rmse:4.33931
# [181]	validation_0-rmse:2.19246	validation_1-rmse:4.33916
# [182]	validation_0-rmse:2.18776	validation_1-rmse:4.33855
# [183]	validation_0-rmse:2.18570	validation_1-rmse:4.33919
# [184]	validation_0-rmse:2.18147	validation_1-rmse:4.33826
# [185]	validation_0-rmse:2.17692	validation_1-rmse:4.33954
# [186]	validation_0-rmse:2.17477	validation_1-rmse:4.33959
# [187]	validation_0-rmse:2.17005	validation_1-rmse:4.33987
# [188]	validation_0-rmse:2.16526	validation_1-rmse:4.34061
# [189]	validation_0-rmse:2.16291	validation_1-rmse:4.34024
# [190]	validation_0-rmse:2.15433	validation_1-rmse:4.33845
# [191]	validation_0-rmse:2.15002	validation_1-rmse:4.33822
# [192]	validation_0-rmse:2.14575	validation_1-rmse:4.33906
# [193]	validation_0-rmse:2.14363	validation_1-rmse:4.33903
# [194]	validation_0-rmse:2.13893	validation_1-rmse:4.34050
# [195]	validation_0-rmse:2.13571	validation_1-rmse:4.34137
# [196]	validation_0-rmse:2.13262	validation_1-rmse:4.34134
# [197]	validation_0-rmse:2.13059	validation_1-rmse:4.34113
# [198]	validation_0-rmse:2.12736	validation_1-rmse:4.34116
# [199]	validation_0-rmse:2.12308	validation_1-rmse:4.34044
# [200]	validation_0-rmse:2.12025	validation_1-rmse:4.34039
# [201]	validation_0-rmse:2.11835	validation_1-rmse:4.34032
# [202]	validation_0-rmse:2.11633	validation_1-rmse:4.34030
# [203]	validation_0-rmse:2.11361	validation_1-rmse:4.34090
# [204]	validation_0-rmse:2.11045	validation_1-rmse:4.34038
# [205]	validation_0-rmse:2.10685	validation_1-rmse:4.34174
# [206]	validation_0-rmse:2.10023	validation_1-rmse:4.34222
# [207]	validation_0-rmse:2.09760	validation_1-rmse:4.34251
# [208]	validation_0-rmse:2.09297	validation_1-rmse:4.34270
# [209]	validation_0-rmse:2.09051	validation_1-rmse:4.34279
# [210]	validation_0-rmse:2.08898	validation_1-rmse:4.34264
# [211]	validation_0-rmse:2.08749	validation_1-rmse:4.34224
# [212]	validation_0-rmse:2.08338	validation_1-rmse:4.33992
# [213]	validation_0-rmse:2.08016	validation_1-rmse:4.34029
# [214]	validation_0-rmse:2.07714	validation_1-rmse:4.34017
# [215]	validation_0-rmse:2.07350	validation_1-rmse:4.33864
# [216]	validation_0-rmse:2.07179	validation_1-rmse:4.33829
# [217]	validation_0-rmse:2.07007	validation_1-rmse:4.33833
# [218]	validation_0-rmse:2.06708	validation_1-rmse:4.33891
# [219]	validation_0-rmse:2.06110	validation_1-rmse:4.33929
# [220]	validation_0-rmse:2.05902	validation_1-rmse:4.33949
# [221]	validation_0-rmse:2.05798	validation_1-rmse:4.33939
# [222]	validation_0-rmse:2.05519	validation_1-rmse:4.33915
# [223]	validation_0-rmse:2.05380	validation_1-rmse:4.33893
# [224]	validation_0-rmse:2.04966	validation_1-rmse:4.33884
# [225]	validation_0-rmse:2.04583	validation_1-rmse:4.33777
# [226]	validation_0-rmse:2.04167	validation_1-rmse:4.33728
# [227]	validation_0-rmse:2.03879	validation_1-rmse:4.33823
# [228]	validation_0-rmse:2.03575	validation_1-rmse:4.33812
# [229]	validation_0-rmse:2.03253	validation_1-rmse:4.33764
# [230]	validation_0-rmse:2.02985	validation_1-rmse:4.33790
# [231]	validation_0-rmse:2.02685	validation_1-rmse:4.33756
# [232]	validation_0-rmse:2.02156	validation_1-rmse:4.33723
# [233]	validation_0-rmse:2.02014	validation_1-rmse:4.33749
# [234]	validation_0-rmse:2.01883	validation_1-rmse:4.33743
# [235]	validation_0-rmse:2.01623	validation_1-rmse:4.33838
# [236]	validation_0-rmse:2.01430	validation_1-rmse:4.33850
# [237]	validation_0-rmse:2.00802	validation_1-rmse:4.33805
# [238]	validation_0-rmse:2.00570	validation_1-rmse:4.33825
# [239]	validation_0-rmse:2.00305	validation_1-rmse:4.33850
# [240]	validation_0-rmse:1.99713	validation_1-rmse:4.33791
# [241]	validation_0-rmse:1.99231	validation_1-rmse:4.33851
# [242]	validation_0-rmse:1.99077	validation_1-rmse:4.33750
# [243]	validation_0-rmse:1.98667	validation_1-rmse:4.33725
# [244]	validation_0-rmse:1.98020	validation_1-rmse:4.33671
# [245]	validation_0-rmse:1.97413	validation_1-rmse:4.33555
# [246]	validation_0-rmse:1.97028	validation_1-rmse:4.33521
# [247]	validation_0-rmse:1.96708	validation_1-rmse:4.33421
# [248]	validation_0-rmse:1.96379	validation_1-rmse:4.33526
# [249]	validation_0-rmse:1.95890	validation_1-rmse:4.33405
# [250]	validation_0-rmse:1.95591	validation_1-rmse:4.33397
# [251]	validation_0-rmse:1.95294	validation_1-rmse:4.33265
# [252]	validation_0-rmse:1.94875	validation_1-rmse:4.33278
# [253]	validation_0-rmse:1.94391	validation_1-rmse:4.33322
# [254]	validation_0-rmse:1.94015	validation_1-rmse:4.33253
# [255]	validation_0-rmse:1.93716	validation_1-rmse:4.33183
# [256]	validation_0-rmse:1.93374	validation_1-rmse:4.33049
# [257]	validation_0-rmse:1.92849	validation_1-rmse:4.33075
# [258]	validation_0-rmse:1.92183	validation_1-rmse:4.32947
# [259]	validation_0-rmse:1.91851	validation_1-rmse:4.32933
# [260]	validation_0-rmse:1.91286	validation_1-rmse:4.32904
# [261]	validation_0-rmse:1.91087	validation_1-rmse:4.32930
# [262]	validation_0-rmse:1.90881	validation_1-rmse:4.32923
# [263]	validation_0-rmse:1.90449	validation_1-rmse:4.32954
# [264]	validation_0-rmse:1.90274	validation_1-rmse:4.33019
# [265]	validation_0-rmse:1.89767	validation_1-rmse:4.32868
# [266]	validation_0-rmse:1.89480	validation_1-rmse:4.32859
# [267]	validation_0-rmse:1.89120	validation_1-rmse:4.32760
# [268]	validation_0-rmse:1.88709	validation_1-rmse:4.32881
# [269]	validation_0-rmse:1.88172	validation_1-rmse:4.32834
# [270]	validation_0-rmse:1.87821	validation_1-rmse:4.32715
# [271]	validation_0-rmse:1.87466	validation_1-rmse:4.32740
# [272]	validation_0-rmse:1.87122	validation_1-rmse:4.32753
# [273]	validation_0-rmse:1.86693	validation_1-rmse:4.32733
# [274]	validation_0-rmse:1.86543	validation_1-rmse:4.32811
# [275]	validation_0-rmse:1.85929	validation_1-rmse:4.32684
# [276]	validation_0-rmse:1.85626	validation_1-rmse:4.32647
# [277]	validation_0-rmse:1.85247	validation_1-rmse:4.32720
# [278]	validation_0-rmse:1.85095	validation_1-rmse:4.32735
# [279]	validation_0-rmse:1.84564	validation_1-rmse:4.32647
# [280]	validation_0-rmse:1.84201	validation_1-rmse:4.32691
# [281]	validation_0-rmse:1.83791	validation_1-rmse:4.32740
# [282]	validation_0-rmse:1.83622	validation_1-rmse:4.32751
# [283]	validation_0-rmse:1.83395	validation_1-rmse:4.32789
# [284]	validation_0-rmse:1.83101	validation_1-rmse:4.32820
# [285]	validation_0-rmse:1.82649	validation_1-rmse:4.32664
# [286]	validation_0-rmse:1.82409	validation_1-rmse:4.32663
# [287]	validation_0-rmse:1.82230	validation_1-rmse:4.32708
# [288]	validation_0-rmse:1.81911	validation_1-rmse:4.32729
# [289]	validation_0-rmse:1.81606	validation_1-rmse:4.32757
# [290]	validation_0-rmse:1.81352	validation_1-rmse:4.32679
# [291]	validation_0-rmse:1.80848	validation_1-rmse:4.32786
# [292]	validation_0-rmse:1.80736	validation_1-rmse:4.32779
# [293]	validation_0-rmse:1.80556	validation_1-rmse:4.32772
# [294]	validation_0-rmse:1.80292	validation_1-rmse:4.32912
# [295]	validation_0-rmse:1.79880	validation_1-rmse:4.32962
# [296]	validation_0-rmse:1.79413	validation_1-rmse:4.32904
# [297]	validation_0-rmse:1.79263	validation_1-rmse:4.32905
# [298]	validation_0-rmse:1.79117	validation_1-rmse:4.32901
# [299]	validation_0-rmse:1.78700	validation_1-rmse:4.32937
# [300]	validation_0-rmse:1.78619	validation_1-rmse:4.32966
# [301]	validation_0-rmse:1.78361	validation_1-rmse:4.32914
# [302]	validation_0-rmse:1.77729	validation_1-rmse:4.32783
# [303]	validation_0-rmse:1.77291	validation_1-rmse:4.32758
# [304]	validation_0-rmse:1.77015	validation_1-rmse:4.32738
# [305]	validation_0-rmse:1.76802	validation_1-rmse:4.32778
# [306]	validation_0-rmse:1.76439	validation_1-rmse:4.32743
# [307]	validation_0-rmse:1.76031	validation_1-rmse:4.32763
# [308]	validation_0-rmse:1.75880	validation_1-rmse:4.32742
# [309]	validation_0-rmse:1.75505	validation_1-rmse:4.32743
# [310]	validation_0-rmse:1.75192	validation_1-rmse:4.32730
# [311]	validation_0-rmse:1.74954	validation_1-rmse:4.32730
# [312]	validation_0-rmse:1.74509	validation_1-rmse:4.32810
# [313]	validation_0-rmse:1.74367	validation_1-rmse:4.32789
# [314]	validation_0-rmse:1.74224	validation_1-rmse:4.32757
# [315]	validation_0-rmse:1.73906	validation_1-rmse:4.32760
# [316]	validation_0-rmse:1.73720	validation_1-rmse:4.32703
# [317]	validation_0-rmse:1.73370	validation_1-rmse:4.32731
# [318]	validation_0-rmse:1.73110	validation_1-rmse:4.32733
# [319]	validation_0-rmse:1.73020	validation_1-rmse:4.32695
# [320]	validation_0-rmse:1.72568	validation_1-rmse:4.32708
# [321]	validation_0-rmse:1.72112	validation_1-rmse:4.32700
# [322]	validation_0-rmse:1.71963	validation_1-rmse:4.32733
# [323]	validation_0-rmse:1.71812	validation_1-rmse:4.32717
# [324]	validation_0-rmse:1.71673	validation_1-rmse:4.32724
# [325]	validation_0-rmse:1.71449	validation_1-rmse:4.32664
# [326]	validation_0-rmse:1.70998	validation_1-rmse:4.32675
# [327]	validation_0-rmse:1.70793	validation_1-rmse:4.32739
# [328]	validation_0-rmse:1.70465	validation_1-rmse:4.32674
# [329]	validation_0-rmse:1.70085	validation_1-rmse:4.32602
# [330]	validation_0-rmse:1.69857	validation_1-rmse:4.32612
# [331]	validation_0-rmse:1.69717	validation_1-rmse:4.32612
# [332]	validation_0-rmse:1.69387	validation_1-rmse:4.32612
# [333]	validation_0-rmse:1.68968	validation_1-rmse:4.32593
# [334]	validation_0-rmse:1.68898	validation_1-rmse:4.32598
# [335]	validation_0-rmse:1.68697	validation_1-rmse:4.32683
# [336]	validation_0-rmse:1.68308	validation_1-rmse:4.32669
# [337]	validation_0-rmse:1.67964	validation_1-rmse:4.32741
# [338]	validation_0-rmse:1.67716	validation_1-rmse:4.32757
# [339]	validation_0-rmse:1.67369	validation_1-rmse:4.32732
# [340]	validation_0-rmse:1.67163	validation_1-rmse:4.32859
# [341]	validation_0-rmse:1.66715	validation_1-rmse:4.32892
# [342]	validation_0-rmse:1.66125	validation_1-rmse:4.32867
# [343]	validation_0-rmse:1.65902	validation_1-rmse:4.32812
# [344]	validation_0-rmse:1.65397	validation_1-rmse:4.32855
# [345]	validation_0-rmse:1.65191	validation_1-rmse:4.32809
# [346]	validation_0-rmse:1.64773	validation_1-rmse:4.32886
# [347]	validation_0-rmse:1.64651	validation_1-rmse:4.32889
# [348]	validation_0-rmse:1.64477	validation_1-rmse:4.32905
# [349]	validation_0-rmse:1.64327	validation_1-rmse:4.32920
# [350]	validation_0-rmse:1.64084	validation_1-rmse:4.32962
# [351]	validation_0-rmse:1.63778	validation_1-rmse:4.32942
# [352]	validation_0-rmse:1.63564	validation_1-rmse:4.32866
# [353]	validation_0-rmse:1.63301	validation_1-rmse:4.32877
# [354]	validation_0-rmse:1.62910	validation_1-rmse:4.33032
# [355]	validation_0-rmse:1.62561	validation_1-rmse:4.32940
# [356]	validation_0-rmse:1.62416	validation_1-rmse:4.32975
# [357]	validation_0-rmse:1.62303	validation_1-rmse:4.32973
# [358]	validation_0-rmse:1.62245	validation_1-rmse:4.32951
# [359]	validation_0-rmse:1.62100	validation_1-rmse:4.32954
# [360]	validation_0-rmse:1.61885	validation_1-rmse:4.32915
# [361]	validation_0-rmse:1.61586	validation_1-rmse:4.32868
# [362]	validation_0-rmse:1.61319	validation_1-rmse:4.32840
# [363]	validation_0-rmse:1.61060	validation_1-rmse:4.32910
# [364]	validation_0-rmse:1.60917	validation_1-rmse:4.32931
# [365]	validation_0-rmse:1.60637	validation_1-rmse:4.32930
# [366]	validation_0-rmse:1.60348	validation_1-rmse:4.32967
# [367]	validation_0-rmse:1.60254	validation_1-rmse:4.32979
# [368]	validation_0-rmse:1.59858	validation_1-rmse:4.33052
# [369]	validation_0-rmse:1.59501	validation_1-rmse:4.32920
# [370]	validation_0-rmse:1.59262	validation_1-rmse:4.32877
# [371]	validation_0-rmse:1.58845	validation_1-rmse:4.32890
# [372]	validation_0-rmse:1.58601	validation_1-rmse:4.32893
# [373]	validation_0-rmse:1.58382	validation_1-rmse:4.32878
# [374]	validation_0-rmse:1.57975	validation_1-rmse:4.32920
# [375]	validation_0-rmse:1.57683	validation_1-rmse:4.32828
# [376]	validation_0-rmse:1.57541	validation_1-rmse:4.32591
# [377]	validation_0-rmse:1.57314	validation_1-rmse:4.32566
# [378]	validation_0-rmse:1.57180	validation_1-rmse:4.32513
# [379]	validation_0-rmse:1.56976	validation_1-rmse:4.32500
# [380]	validation_0-rmse:1.56846	validation_1-rmse:4.32340
# [381]	validation_0-rmse:1.56496	validation_1-rmse:4.32341
# [382]	validation_0-rmse:1.56301	validation_1-rmse:4.32306
# [383]	validation_0-rmse:1.56177	validation_1-rmse:4.32327
# [384]	validation_0-rmse:1.55959	validation_1-rmse:4.32309
# [385]	validation_0-rmse:1.55695	validation_1-rmse:4.32349
# [386]	validation_0-rmse:1.55229	validation_1-rmse:4.32367
# [387]	validation_0-rmse:1.55132	validation_1-rmse:4.32345
# [388]	validation_0-rmse:1.55054	validation_1-rmse:4.32300
# [389]	validation_0-rmse:1.54898	validation_1-rmse:4.32290
# [390]	validation_0-rmse:1.54651	validation_1-rmse:4.32270
# [391]	validation_0-rmse:1.54289	validation_1-rmse:4.32248
# [392]	validation_0-rmse:1.54089	validation_1-rmse:4.32318
# [393]	validation_0-rmse:1.54005	validation_1-rmse:4.32341
# [394]	validation_0-rmse:1.53401	validation_1-rmse:4.32412
# [395]	validation_0-rmse:1.53194	validation_1-rmse:4.32412
# [396]	validation_0-rmse:1.53072	validation_1-rmse:4.32247
# [397]	validation_0-rmse:1.52908	validation_1-rmse:4.32269
# [398]	validation_0-rmse:1.52747	validation_1-rmse:4.32267
# [399]	validation_0-rmse:1.52522	validation_1-rmse:4.32288
# [400]	validation_0-rmse:1.52183	validation_1-rmse:4.32257
# [401]	validation_0-rmse:1.51993	validation_1-rmse:4.32191
# [402]	validation_0-rmse:1.51739	validation_1-rmse:4.32231
# [403]	validation_0-rmse:1.51541	validation_1-rmse:4.32219
# [404]	validation_0-rmse:1.51449	validation_1-rmse:4.32220
# [405]	validation_0-rmse:1.51266	validation_1-rmse:4.32237
# [406]	validation_0-rmse:1.51025	validation_1-rmse:4.32184
# [407]	validation_0-rmse:1.50849	validation_1-rmse:4.32162
# [408]	validation_0-rmse:1.50616	validation_1-rmse:4.32136
# [409]	validation_0-rmse:1.50360	validation_1-rmse:4.32181
# [410]	validation_0-rmse:1.50173	validation_1-rmse:4.32150
# [411]	validation_0-rmse:1.49755	validation_1-rmse:4.32233
# [412]	validation_0-rmse:1.49531	validation_1-rmse:4.32198
# [413]	validation_0-rmse:1.49000	validation_1-rmse:4.32258
# [414]	validation_0-rmse:1.48657	validation_1-rmse:4.32229
# [415]	validation_0-rmse:1.48546	validation_1-rmse:4.32229
# [416]	validation_0-rmse:1.48324	validation_1-rmse:4.32242
# [417]	validation_0-rmse:1.48176	validation_1-rmse:4.32268
# [418]	validation_0-rmse:1.47845	validation_1-rmse:4.32228
# [419]	validation_0-rmse:1.47474	validation_1-rmse:4.32328
# [420]	validation_0-rmse:1.47195	validation_1-rmse:4.32361
# [421]	validation_0-rmse:1.46681	validation_1-rmse:4.32411
# [422]	validation_0-rmse:1.46394	validation_1-rmse:4.32338
# [423]	validation_0-rmse:1.46195	validation_1-rmse:4.32331
# [424]	validation_0-rmse:1.46059	validation_1-rmse:4.32188
# [425]	validation_0-rmse:1.46019	validation_1-rmse:4.32192
# [426]	validation_0-rmse:1.45822	validation_1-rmse:4.32196
# [427]	validation_0-rmse:1.45477	validation_1-rmse:4.32160
# [428]	validation_0-rmse:1.45317	validation_1-rmse:4.32174
# [429]	validation_0-rmse:1.45229	validation_1-rmse:4.32197
# [430]	validation_0-rmse:1.45031	validation_1-rmse:4.32201
# [431]	validation_0-rmse:1.44578	validation_1-rmse:4.32210
# [432]	validation_0-rmse:1.44297	validation_1-rmse:4.32203
# [433]	validation_0-rmse:1.44233	validation_1-rmse:4.32208
# [434]	validation_0-rmse:1.43901	validation_1-rmse:4.32155
# [435]	validation_0-rmse:1.43737	validation_1-rmse:4.32153
# [436]	validation_0-rmse:1.43502	validation_1-rmse:4.32176
# [437]	validation_0-rmse:1.43148	validation_1-rmse:4.32179
# [438]	validation_0-rmse:1.42600	validation_1-rmse:4.32239
# [439]	validation_0-rmse:1.42440	validation_1-rmse:4.32256
# [440]	validation_0-rmse:1.42243	validation_1-rmse:4.32259
# [441]	validation_0-rmse:1.42083	validation_1-rmse:4.32272
# [442]	validation_0-rmse:1.41945	validation_1-rmse:4.32256
# [443]	validation_0-rmse:1.41767	validation_1-rmse:4.32258
# [444]	validation_0-rmse:1.41732	validation_1-rmse:4.32260
# [445]	validation_0-rmse:1.41559	validation_1-rmse:4.32244
# [446]	validation_0-rmse:1.41375	validation_1-rmse:4.32279
# [447]	validation_0-rmse:1.41133	validation_1-rmse:4.32298
# [448]	validation_0-rmse:1.41066	validation_1-rmse:4.32263
# [449]	validation_0-rmse:1.40869	validation_1-rmse:4.32198
# [450]	validation_0-rmse:1.40584	validation_1-rmse:4.32150
# [451]	validation_0-rmse:1.40314	validation_1-rmse:4.32191
# [452]	validation_0-rmse:1.40047	validation_1-rmse:4.32172
# [453]	validation_0-rmse:1.39892	validation_1-rmse:4.32152
# [454]	validation_0-rmse:1.39552	validation_1-rmse:4.32140
# [455]	validation_0-rmse:1.39369	validation_1-rmse:4.32120
# [456]	validation_0-rmse:1.39334	validation_1-rmse:4.32127
# [457]	validation_0-rmse:1.39094	validation_1-rmse:4.32098
# [458]	validation_0-rmse:1.39013	validation_1-rmse:4.32079
# [459]	validation_0-rmse:1.38849	validation_1-rmse:4.32023
# [460]	validation_0-rmse:1.38775	validation_1-rmse:4.32006
# [461]	validation_0-rmse:1.38517	validation_1-rmse:4.32065
# [462]	validation_0-rmse:1.38221	validation_1-rmse:4.32071
# [463]	validation_0-rmse:1.38056	validation_1-rmse:4.32124
# [464]	validation_0-rmse:1.37870	validation_1-rmse:4.32115
# [465]	validation_0-rmse:1.37581	validation_1-rmse:4.32113
# [466]	validation_0-rmse:1.37298	validation_1-rmse:4.32118
# [467]	validation_0-rmse:1.37108	validation_1-rmse:4.32119
# [468]	validation_0-rmse:1.36913	validation_1-rmse:4.32178
# [469]	validation_0-rmse:1.36832	validation_1-rmse:4.32192
# [470]	validation_0-rmse:1.36681	validation_1-rmse:4.32162
# [471]	validation_0-rmse:1.36481	validation_1-rmse:4.32126
# [472]	validation_0-rmse:1.36242	validation_1-rmse:4.32100
# [473]	validation_0-rmse:1.36175	validation_1-rmse:4.32088
# [474]	validation_0-rmse:1.36115	validation_1-rmse:4.32098
# [475]	validation_0-rmse:1.35933	validation_1-rmse:4.32017
# [476]	validation_0-rmse:1.35680	validation_1-rmse:4.31997
# [477]	validation_0-rmse:1.35397	validation_1-rmse:4.32042
# [478]	validation_0-rmse:1.35112	validation_1-rmse:4.31994
# [479]	validation_0-rmse:1.35059	validation_1-rmse:4.31995
# [480]	validation_0-rmse:1.34724	validation_1-rmse:4.31931
# [481]	validation_0-rmse:1.34421	validation_1-rmse:4.31964
# [482]	validation_0-rmse:1.34316	validation_1-rmse:4.31991
# [483]	validation_0-rmse:1.34107	validation_1-rmse:4.31929
# [484]	validation_0-rmse:1.33948	validation_1-rmse:4.31933
# [485]	validation_0-rmse:1.33723	validation_1-rmse:4.31915
# [486]	validation_0-rmse:1.33493	validation_1-rmse:4.31936
# [487]	validation_0-rmse:1.33061	validation_1-rmse:4.31927
# [488]	validation_0-rmse:1.32899	validation_1-rmse:4.31909
# [489]	validation_0-rmse:1.32720	validation_1-rmse:4.31906
# [490]	validation_0-rmse:1.32563	validation_1-rmse:4.31937
# [491]	validation_0-rmse:1.32171	validation_1-rmse:4.31967
# [492]	validation_0-rmse:1.31853	validation_1-rmse:4.31917
# [493]	validation_0-rmse:1.31459	validation_1-rmse:4.31943
# [494]	validation_0-rmse:1.31377	validation_1-rmse:4.31975
# [495]	validation_0-rmse:1.31223	validation_1-rmse:4.31977
# [496]	validation_0-rmse:1.31154	validation_1-rmse:4.31974
# [497]	validation_0-rmse:1.31011	validation_1-rmse:4.32003
# [498]	validation_0-rmse:1.30917	validation_1-rmse:4.32029
# [499]	validation_0-rmse:1.30713	validation_1-rmse:4.31985
# [500]	validation_0-rmse:1.30427	validation_1-rmse:4.32049
# [501]	validation_0-rmse:1.30160	validation_1-rmse:4.32041
# [502]	validation_0-rmse:1.29862	validation_1-rmse:4.32055
# [503]	validation_0-rmse:1.29747	validation_1-rmse:4.32063
# [504]	validation_0-rmse:1.29401	validation_1-rmse:4.32077
# [505]	validation_0-rmse:1.29260	validation_1-rmse:4.32068
# [506]	validation_0-rmse:1.29183	validation_1-rmse:4.32073
# [507]	validation_0-rmse:1.29018	validation_1-rmse:4.32114
# [508]	validation_0-rmse:1.28849	validation_1-rmse:4.32145
# [509]	validation_0-rmse:1.28539	validation_1-rmse:4.32070
# [510]	validation_0-rmse:1.28291	validation_1-rmse:4.32068
# [511]	validation_0-rmse:1.28011	validation_1-rmse:4.32081
# [512]	validation_0-rmse:1.27797	validation_1-rmse:4.32053
# [513]	validation_0-rmse:1.27425	validation_1-rmse:4.32083
# [514]	validation_0-rmse:1.27396	validation_1-rmse:4.32079
# [515]	validation_0-rmse:1.27343	validation_1-rmse:4.32046
# [516]	validation_0-rmse:1.27108	validation_1-rmse:4.32029
# [517]	validation_0-rmse:1.26814	validation_1-rmse:4.32027
# [518]	validation_0-rmse:1.26592	validation_1-rmse:4.32066
# [519]	validation_0-rmse:1.26474	validation_1-rmse:4.32053
# [520]	validation_0-rmse:1.26173	validation_1-rmse:4.32056
# [521]	validation_0-rmse:1.25976	validation_1-rmse:4.32134
# [522]	validation_0-rmse:1.25766	validation_1-rmse:4.32147
# [523]	validation_0-rmse:1.25534	validation_1-rmse:4.32189
# [524]	validation_0-rmse:1.25333	validation_1-rmse:4.32210
# [525]	validation_0-rmse:1.25159	validation_1-rmse:4.32259
# [526]	validation_0-rmse:1.24868	validation_1-rmse:4.32245
# [527]	validation_0-rmse:1.24651	validation_1-rmse:4.32248
# [528]	validation_0-rmse:1.24464	validation_1-rmse:4.32247
# [529]	validation_0-rmse:1.24323	validation_1-rmse:4.32254
# [530]	validation_0-rmse:1.24194	validation_1-rmse:4.32285
# [531]	validation_0-rmse:1.24129	validation_1-rmse:4.32291
# [532]	validation_0-rmse:1.23973	validation_1-rmse:4.32270
# [533]	validation_0-rmse:1.23860	validation_1-rmse:4.32286
# [534]	validation_0-rmse:1.23834	validation_1-rmse:4.32296
# [535]	validation_0-rmse:1.23599	validation_1-rmse:4.32350
# [536]	validation_0-rmse:1.23359	validation_1-rmse:4.32399
# [537]	validation_0-rmse:1.23236	validation_1-rmse:4.32422
# [538]	validation_0-rmse:1.22921	validation_1-rmse:4.32485
# [539]	validation_0-rmse:1.22665	validation_1-rmse:4.32455
# [540]	validation_0-rmse:1.22530	validation_1-rmse:4.32498
# [541]	validation_0-rmse:1.22181	validation_1-rmse:4.32498
# [542]	validation_0-rmse:1.22015	validation_1-rmse:4.32480
# [543]	validation_0-rmse:1.21759	validation_1-rmse:4.32548
# [544]	validation_0-rmse:1.21663	validation_1-rmse:4.32561
# [545]	validation_0-rmse:1.21425	validation_1-rmse:4.32550
# [546]	validation_0-rmse:1.21168	validation_1-rmse:4.32538
# [547]	validation_0-rmse:1.20966	validation_1-rmse:4.32500
# [548]	validation_0-rmse:1.20901	validation_1-rmse:4.32506
# [549]	validation_0-rmse:1.20852	validation_1-rmse:4.32497
# [550]	validation_0-rmse:1.20586	validation_1-rmse:4.32453
# [551]	validation_0-rmse:1.20225	validation_1-rmse:4.32510
# [552]	validation_0-rmse:1.20018	validation_1-rmse:4.32472
# [553]	validation_0-rmse:1.19767	validation_1-rmse:4.32486
# [554]	validation_0-rmse:1.19603	validation_1-rmse:4.32466
# [555]	validation_0-rmse:1.19334	validation_1-rmse:4.32416
# [556]	validation_0-rmse:1.19175	validation_1-rmse:4.32409
# [557]	validation_0-rmse:1.18867	validation_1-rmse:4.32451
# [558]	validation_0-rmse:1.18772	validation_1-rmse:4.32452
# [559]	validation_0-rmse:1.18583	validation_1-rmse:4.32410
# [560]	validation_0-rmse:1.18386	validation_1-rmse:4.32419
# [561]	validation_0-rmse:1.18158	validation_1-rmse:4.32373
# [562]	validation_0-rmse:1.17923	validation_1-rmse:4.32336
# [563]	validation_0-rmse:1.17697	validation_1-rmse:4.32356
# [564]	validation_0-rmse:1.17407	validation_1-rmse:4.32408
# [565]	validation_0-rmse:1.17323	validation_1-rmse:4.32412
# [566]	validation_0-rmse:1.17081	validation_1-rmse:4.32337
# [567]	validation_0-rmse:1.16813	validation_1-rmse:4.32314
# [568]	validation_0-rmse:1.16581	validation_1-rmse:4.32213
# [569]	validation_0-rmse:1.16524	validation_1-rmse:4.32224
# [570]	validation_0-rmse:1.16282	validation_1-rmse:4.32132
# [571]	validation_0-rmse:1.15973	validation_1-rmse:4.32144
# [572]	validation_0-rmse:1.15691	validation_1-rmse:4.32137
# [573]	validation_0-rmse:1.15509	validation_1-rmse:4.32154
# [574]	validation_0-rmse:1.15410	validation_1-rmse:4.32149
# [575]	validation_0-rmse:1.15337	validation_1-rmse:4.32161
# [576]	validation_0-rmse:1.14981	validation_1-rmse:4.32133
# [577]	validation_0-rmse:1.14782	validation_1-rmse:4.32151
# [578]	validation_0-rmse:1.14533	validation_1-rmse:4.32146
# [579]	validation_0-rmse:1.14391	validation_1-rmse:4.32118
# [580]	validation_0-rmse:1.14262	validation_1-rmse:4.32133
# [581]	validation_0-rmse:1.14209	validation_1-rmse:4.32122
# [582]	validation_0-rmse:1.14142	validation_1-rmse:4.32129
# [583]	validation_0-rmse:1.14116	validation_1-rmse:4.32139
# [584]	validation_0-rmse:1.14053	validation_1-rmse:4.32144
# [585]	validation_0-rmse:1.13979	validation_1-rmse:4.32143
# [586]	validation_0-rmse:1.13847	validation_1-rmse:4.32147
# [587]	validation_0-rmse:1.13696	validation_1-rmse:4.32155
# [588]	validation_0-rmse:1.13313	validation_1-rmse:4.32094
# [589]	validation_0-rmse:1.13060	validation_1-rmse:4.32056
# >>> Using model to predict target NEE_L3.1_L3.3_CUT_50_QCF in unseen test data ...
# >>> Using model to calculate SHAP feature importance based on unseen test data ...
# >>> Calculating prediction scores based on predicting unseen test data of NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Collecting results, details about training and testing can be accessed by calling .report_traintest().
# >>> Done.
#
# Gap-filling 2024 ...
#
# Gap-filling using final model ...
# >>> Using final model on all data to predict target NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Using final model on all data to calculate SHAP feature importance ...
# >>> Calculating prediction scores based on all data predicting NEE_L3.1_L3.3_CUT_50_QCF ...
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF where all features are available ... predicted 9175 records.
# >>> Collecting results for final model ...
# >>> Filling 2571 missing records in target with predictions from final model ...
# >>> Storing gap-filled time series in variable NEE_L3.1_L3.3_CUT_50_QCF_gfXG ...
# >>> Restoring original timestamp in results ...
#
# Gap-filling 28469 remaining missing records in NEE_L3.1_L3.3_CUT_50_QCF_gfXG using fallback model ...
# >>> Fallback model is trained on NEE_L3.1_L3.3_CUT_50_QCF_gfXG and timestamp info ...
# ++ Added new columns with timestamp info: ['.YEAR', '.SEASON', '.SEASON_SIN', '.SEASON_COS', '.MONTH', '.MONTH_SIN', '.MONTH_COS', '.WEEK', '.WEEK_SIN', '.WEEK_COS', '.DOY', '.DOY_SIN', '.DOY_COS', '.HOUR', '.HOUR_SIN', '.HOUR_COS', '.YEARMONTH', '.YEARDOY', '.YEARWEEK'] (ONLY FALLBACK)
# [0]	validation_0-rmse:6.51649	validation_1-rmse:6.51649
# [1]	validation_0-rmse:6.31336	validation_1-rmse:6.31336
# [2]	validation_0-rmse:6.12400	validation_1-rmse:6.12400
# [3]	validation_0-rmse:5.94716	validation_1-rmse:5.94716
# [4]	validation_0-rmse:5.78248	validation_1-rmse:5.78248
# [5]	validation_0-rmse:5.62950	validation_1-rmse:5.62950
# [6]	validation_0-rmse:5.48717	validation_1-rmse:5.48717
# [7]	validation_0-rmse:5.35262	validation_1-rmse:5.35262
# [8]	validation_0-rmse:5.22253	validation_1-rmse:5.22253
# [9]	validation_0-rmse:5.10174	validation_1-rmse:5.10174
# [10]	validation_0-rmse:4.99325	validation_1-rmse:4.99325
# [11]	validation_0-rmse:4.88822	validation_1-rmse:4.88822
# [12]	validation_0-rmse:4.79318	validation_1-rmse:4.79318
# [13]	validation_0-rmse:4.70352	validation_1-rmse:4.70352
# [14]	validation_0-rmse:4.62239	validation_1-rmse:4.62239
# [15]	validation_0-rmse:4.54528	validation_1-rmse:4.54528
# [16]	validation_0-rmse:4.47328	validation_1-rmse:4.47328
# [17]	validation_0-rmse:4.40041	validation_1-rmse:4.40041
# [18]	validation_0-rmse:4.33747	validation_1-rmse:4.33747
# [19]	validation_0-rmse:4.27890	validation_1-rmse:4.27890
# [20]	validation_0-rmse:4.21968	validation_1-rmse:4.21968
# [21]	validation_0-rmse:4.16918	validation_1-rmse:4.16918
# [22]	validation_0-rmse:4.12212	validation_1-rmse:4.12212
# [23]	validation_0-rmse:4.07876	validation_1-rmse:4.07876
# [24]	validation_0-rmse:4.03848	validation_1-rmse:4.03848
# [25]	validation_0-rmse:3.99844	validation_1-rmse:3.99844
# [26]	validation_0-rmse:3.96374	validation_1-rmse:3.96374
# [27]	validation_0-rmse:3.93049	validation_1-rmse:3.93049
# [28]	validation_0-rmse:3.89857	validation_1-rmse:3.89857
# [29]	validation_0-rmse:3.86385	validation_1-rmse:3.86385
# [30]	validation_0-rmse:3.83358	validation_1-rmse:3.83358
# [31]	validation_0-rmse:3.80648	validation_1-rmse:3.80648
# [32]	validation_0-rmse:3.77922	validation_1-rmse:3.77922
# [33]	validation_0-rmse:3.75498	validation_1-rmse:3.75498
# [34]	validation_0-rmse:3.73395	validation_1-rmse:3.73395
# [35]	validation_0-rmse:3.71185	validation_1-rmse:3.71185
# [36]	validation_0-rmse:3.69389	validation_1-rmse:3.69389
# [37]	validation_0-rmse:3.67589	validation_1-rmse:3.67589
# [38]	validation_0-rmse:3.65589	validation_1-rmse:3.65589
# [39]	validation_0-rmse:3.63571	validation_1-rmse:3.63571
# [40]	validation_0-rmse:3.61918	validation_1-rmse:3.61918
# [41]	validation_0-rmse:3.60275	validation_1-rmse:3.60275
# [42]	validation_0-rmse:3.58797	validation_1-rmse:3.58797
# [43]	validation_0-rmse:3.57306	validation_1-rmse:3.57306
# [44]	validation_0-rmse:3.55458	validation_1-rmse:3.55458
# [45]	validation_0-rmse:3.54190	validation_1-rmse:3.54190
# [46]	validation_0-rmse:3.52958	validation_1-rmse:3.52958
# [47]	validation_0-rmse:3.51699	validation_1-rmse:3.51699
# [48]	validation_0-rmse:3.50654	validation_1-rmse:3.50654
# [49]	validation_0-rmse:3.49103	validation_1-rmse:3.49103
# [50]	validation_0-rmse:3.47979	validation_1-rmse:3.47979
# [51]	validation_0-rmse:3.46994	validation_1-rmse:3.46994
# [52]	validation_0-rmse:3.46055	validation_1-rmse:3.46055
# [53]	validation_0-rmse:3.45074	validation_1-rmse:3.45074
# [54]	validation_0-rmse:3.44221	validation_1-rmse:3.44221
# [55]	validation_0-rmse:3.43291	validation_1-rmse:3.43291
# [56]	validation_0-rmse:3.42226	validation_1-rmse:3.42226
# [57]	validation_0-rmse:3.41317	validation_1-rmse:3.41317
# [58]	validation_0-rmse:3.40627	validation_1-rmse:3.40627
# [59]	validation_0-rmse:3.39970	validation_1-rmse:3.39970
# [60]	validation_0-rmse:3.39269	validation_1-rmse:3.39269
# [61]	validation_0-rmse:3.38707	validation_1-rmse:3.38707
# [62]	validation_0-rmse:3.37937	validation_1-rmse:3.37937
# [63]	validation_0-rmse:3.37356	validation_1-rmse:3.37356
# [64]	validation_0-rmse:3.36581	validation_1-rmse:3.36581
# [65]	validation_0-rmse:3.35908	validation_1-rmse:3.35908
# [66]	validation_0-rmse:3.35138	validation_1-rmse:3.35138
# [67]	validation_0-rmse:3.34310	validation_1-rmse:3.34310
# [68]	validation_0-rmse:3.33726	validation_1-rmse:3.33726
# [69]	validation_0-rmse:3.33044	validation_1-rmse:3.33044
# [70]	validation_0-rmse:3.32522	validation_1-rmse:3.32522
# [71]	validation_0-rmse:3.31876	validation_1-rmse:3.31876
# [72]	validation_0-rmse:3.31100	validation_1-rmse:3.31100
# [73]	validation_0-rmse:3.30579	validation_1-rmse:3.30579
# [74]	validation_0-rmse:3.30019	validation_1-rmse:3.30019
# [75]	validation_0-rmse:3.29353	validation_1-rmse:3.29353
# [76]	validation_0-rmse:3.28472	validation_1-rmse:3.28472
# [77]	validation_0-rmse:3.28046	validation_1-rmse:3.28046
# [78]	validation_0-rmse:3.27233	validation_1-rmse:3.27233
# [79]	validation_0-rmse:3.26777	validation_1-rmse:3.26777
# [80]	validation_0-rmse:3.25975	validation_1-rmse:3.25975
# [81]	validation_0-rmse:3.25648	validation_1-rmse:3.25648
# [82]	validation_0-rmse:3.25009	validation_1-rmse:3.25009
# [83]	validation_0-rmse:3.24472	validation_1-rmse:3.24472
# [84]	validation_0-rmse:3.24104	validation_1-rmse:3.24104
# [85]	validation_0-rmse:3.23631	validation_1-rmse:3.23631
# [86]	validation_0-rmse:3.23268	validation_1-rmse:3.23268
# [87]	validation_0-rmse:3.22996	validation_1-rmse:3.22996
# [88]	validation_0-rmse:3.22576	validation_1-rmse:3.22576
# [89]	validation_0-rmse:3.22060	validation_1-rmse:3.22060
# [90]	validation_0-rmse:3.21610	validation_1-rmse:3.21610
# [91]	validation_0-rmse:3.21262	validation_1-rmse:3.21262
# [92]	validation_0-rmse:3.20989	validation_1-rmse:3.20989
# [93]	validation_0-rmse:3.20572	validation_1-rmse:3.20572
# ...
# [2733]	validation_0-rmse:2.02338	validation_1-rmse:2.02338
# [2734]	validation_0-rmse:2.02328	validation_1-rmse:2.02328
# [2735]	validation_0-rmse:2.02318	validation_1-rmse:2.02318
# [2736]	validation_0-rmse:2.02314	validation_1-rmse:2.02314
# [2737]	validation_0-rmse:2.02306	validation_1-rmse:2.02306
# [2738]	validation_0-rmse:2.02298	validation_1-rmse:2.02298
# [2739]	validation_0-rmse:2.02288	validation_1-rmse:2.02288
# [2740]	validation_0-rmse:2.02282	validation_1-rmse:2.02282
# [2741]	validation_0-rmse:2.02274	validation_1-rmse:2.02274
# [2742]	validation_0-rmse:2.02249	validation_1-rmse:2.02249
# [2743]	validation_0-rmse:2.02243	validation_1-rmse:2.02243
# [2744]	validation_0-rmse:2.02238	validation_1-rmse:2.02238
# [2745]	validation_0-rmse:2.02229	validation_1-rmse:2.02229
# [2746]	validation_0-rmse:2.02225	validation_1-rmse:2.02225
# [2747]	validation_0-rmse:2.02217	validation_1-rmse:2.02217
# [2748]	validation_0-rmse:2.02210	validation_1-rmse:2.02210
# [2749]	validation_0-rmse:2.02207	validation_1-rmse:2.02207
# [2750]	validation_0-rmse:2.02203	validation_1-rmse:2.02203
# [2751]	validation_0-rmse:2.02185	validation_1-rmse:2.02185
# [2752]	validation_0-rmse:2.02182	validation_1-rmse:2.02182
# [2753]	validation_0-rmse:2.02177	validation_1-rmse:2.02177
# [2754]	validation_0-rmse:2.02161	validation_1-rmse:2.02161
# [2755]	validation_0-rmse:2.02151	validation_1-rmse:2.02151
# [2756]	validation_0-rmse:2.02135	validation_1-rmse:2.02135
# [2757]	validation_0-rmse:2.02129	validation_1-rmse:2.02129
# [2758]	validation_0-rmse:2.02120	validation_1-rmse:2.02120
# [2759]	validation_0-rmse:2.02114	validation_1-rmse:2.02114
# [2760]	validation_0-rmse:2.02106	validation_1-rmse:2.02106
# [2761]	validation_0-rmse:2.02096	validation_1-rmse:2.02096
# [2762]	validation_0-rmse:2.02088	validation_1-rmse:2.02088
# [2763]	validation_0-rmse:2.02081	validation_1-rmse:2.02081
# [2764]	validation_0-rmse:2.02074	validation_1-rmse:2.02074
# [2765]	validation_0-rmse:2.02061	validation_1-rmse:2.02061
# [2766]	validation_0-rmse:2.02053	validation_1-rmse:2.02053
# [2767]	validation_0-rmse:2.02039	validation_1-rmse:2.02039
# [2768]	validation_0-rmse:2.02030	validation_1-rmse:2.02030
# [2769]	validation_0-rmse:2.02018	validation_1-rmse:2.02018
# [2770]	validation_0-rmse:2.02004	validation_1-rmse:2.02004
# [2771]	validation_0-rmse:2.01999	validation_1-rmse:2.01999
# [2772]	validation_0-rmse:2.01991	validation_1-rmse:2.01991
# [2773]	validation_0-rmse:2.01985	validation_1-rmse:2.01985
# [2774]	validation_0-rmse:2.01979	validation_1-rmse:2.01979
# [2775]	validation_0-rmse:2.01966	validation_1-rmse:2.01966
# [2776]	validation_0-rmse:2.01951	validation_1-rmse:2.01951
# [2777]	validation_0-rmse:2.01939	validation_1-rmse:2.01939
# [2778]	validation_0-rmse:2.01928	validation_1-rmse:2.01928
# [2779]	validation_0-rmse:2.01918	validation_1-rmse:2.01918
# [2780]	validation_0-rmse:2.01908	validation_1-rmse:2.01908
# [2781]	validation_0-rmse:2.01899	validation_1-rmse:2.01899
# [2782]	validation_0-rmse:2.01891	validation_1-rmse:2.01891
# [2783]	validation_0-rmse:2.01883	validation_1-rmse:2.01883
# [2784]	validation_0-rmse:2.01877	validation_1-rmse:2.01877
# [2785]	validation_0-rmse:2.01850	validation_1-rmse:2.01850
# [2786]	validation_0-rmse:2.01844	validation_1-rmse:2.01844
# [2787]	validation_0-rmse:2.01827	validation_1-rmse:2.01827
# [2788]	validation_0-rmse:2.01823	validation_1-rmse:2.01823
# [2789]	validation_0-rmse:2.01821	validation_1-rmse:2.01821
# [2790]	validation_0-rmse:2.01817	validation_1-rmse:2.01817
# [2791]	validation_0-rmse:2.01815	validation_1-rmse:2.01815
# [2792]	validation_0-rmse:2.01813	validation_1-rmse:2.01813
# [2793]	validation_0-rmse:2.01810	validation_1-rmse:2.01810
# [2794]	validation_0-rmse:2.01807	validation_1-rmse:2.01807
# [2795]	validation_0-rmse:2.01797	validation_1-rmse:2.01797
# [2796]	validation_0-rmse:2.01793	validation_1-rmse:2.01793
# [2797]	validation_0-rmse:2.01782	validation_1-rmse:2.01782
# [2798]	validation_0-rmse:2.01776	validation_1-rmse:2.01776
# [2799]	validation_0-rmse:2.01775	validation_1-rmse:2.01775
# [2800]	validation_0-rmse:2.01773	validation_1-rmse:2.01773
# [2801]	validation_0-rmse:2.01772	validation_1-rmse:2.01772
# [2802]	validation_0-rmse:2.01771	validation_1-rmse:2.01771
# [2803]	validation_0-rmse:2.01760	validation_1-rmse:2.01760
# [2804]	validation_0-rmse:2.01744	validation_1-rmse:2.01744
# [2805]	validation_0-rmse:2.01737	validation_1-rmse:2.01737
# [2806]	validation_0-rmse:2.01723	validation_1-rmse:2.01723
# [2807]	validation_0-rmse:2.01720	validation_1-rmse:2.01720
# [2808]	validation_0-rmse:2.01708	validation_1-rmse:2.01708
# [2809]	validation_0-rmse:2.01706	validation_1-rmse:2.01706
# [2810]	validation_0-rmse:2.01705	validation_1-rmse:2.01705
# [2811]	validation_0-rmse:2.01699	validation_1-rmse:2.01699
# [2812]	validation_0-rmse:2.01693	validation_1-rmse:2.01693
# [2813]	validation_0-rmse:2.01669	validation_1-rmse:2.01669
# [2814]	validation_0-rmse:2.01664	validation_1-rmse:2.01664
# [2815]	validation_0-rmse:2.01660	validation_1-rmse:2.01660
# [2816]	validation_0-rmse:2.01652	validation_1-rmse:2.01652
# [2817]	validation_0-rmse:2.01648	validation_1-rmse:2.01648
# [2818]	validation_0-rmse:2.01643	validation_1-rmse:2.01643
# [2819]	validation_0-rmse:2.01635	validation_1-rmse:2.01635
# [2820]	validation_0-rmse:2.01628	validation_1-rmse:2.01628
# [2821]	validation_0-rmse:2.01616	validation_1-rmse:2.01616
# [2822]	validation_0-rmse:2.01610	validation_1-rmse:2.01610
# [2823]	validation_0-rmse:2.01607	validation_1-rmse:2.01607
# [2824]	validation_0-rmse:2.01603	validation_1-rmse:2.01603
# [2825]	validation_0-rmse:2.01591	validation_1-rmse:2.01591
# [2826]	validation_0-rmse:2.01585	validation_1-rmse:2.01585
# [2827]	validation_0-rmse:2.01573	validation_1-rmse:2.01573
# [2828]	validation_0-rmse:2.01568	validation_1-rmse:2.01568
# [2829]	validation_0-rmse:2.01561	validation_1-rmse:2.01561
# [2830]	validation_0-rmse:2.01554	validation_1-rmse:2.01554
# [2831]	validation_0-rmse:2.01550	validation_1-rmse:2.01550
# [2832]	validation_0-rmse:2.01537	validation_1-rmse:2.01537
# [2833]	validation_0-rmse:2.01531	validation_1-rmse:2.01531
# [2834]	validation_0-rmse:2.01528	validation_1-rmse:2.01528
# [2835]	validation_0-rmse:2.01522	validation_1-rmse:2.01522
# [2836]	validation_0-rmse:2.01517	validation_1-rmse:2.01517
# [2837]	validation_0-rmse:2.01516	validation_1-rmse:2.01516
# [2838]	validation_0-rmse:2.01514	validation_1-rmse:2.01514
# [2839]	validation_0-rmse:2.01512	validation_1-rmse:2.01512
# [2840]	validation_0-rmse:2.01511	validation_1-rmse:2.01511
# [2841]	validation_0-rmse:2.01507	validation_1-rmse:2.01507
# [2842]	validation_0-rmse:2.01501	validation_1-rmse:2.01501
# [2843]	validation_0-rmse:2.01483	validation_1-rmse:2.01483
# [2844]	validation_0-rmse:2.01478	validation_1-rmse:2.01478
# [2845]	validation_0-rmse:2.01474	validation_1-rmse:2.01474
# [2846]	validation_0-rmse:2.01467	validation_1-rmse:2.01467
# [2847]	validation_0-rmse:2.01456	validation_1-rmse:2.01456
# [2848]	validation_0-rmse:2.01446	validation_1-rmse:2.01446
# [2849]	validation_0-rmse:2.01441	validation_1-rmse:2.01441
# [2850]	validation_0-rmse:2.01436	validation_1-rmse:2.01436
# [2851]	validation_0-rmse:2.01427	validation_1-rmse:2.01427
# [2852]	validation_0-rmse:2.01418	validation_1-rmse:2.01418
# [2853]	validation_0-rmse:2.01411	validation_1-rmse:2.01411
# [2854]	validation_0-rmse:2.01407	validation_1-rmse:2.01407
# [2855]	validation_0-rmse:2.01391	validation_1-rmse:2.01391
# [2856]	validation_0-rmse:2.01390	validation_1-rmse:2.01390
# [2857]	validation_0-rmse:2.01385	validation_1-rmse:2.01385
# [2858]	validation_0-rmse:2.01380	validation_1-rmse:2.01380
# [2859]	validation_0-rmse:2.01378	validation_1-rmse:2.01378
# [2860]	validation_0-rmse:2.01375	validation_1-rmse:2.01375
# [2861]	validation_0-rmse:2.01360	validation_1-rmse:2.01360
# [2862]	validation_0-rmse:2.01355	validation_1-rmse:2.01355
# [2863]	validation_0-rmse:2.01351	validation_1-rmse:2.01351
# [2864]	validation_0-rmse:2.01344	validation_1-rmse:2.01344
# [2865]	validation_0-rmse:2.01340	validation_1-rmse:2.01340
# [2866]	validation_0-rmse:2.01334	validation_1-rmse:2.01334
# [2867]	validation_0-rmse:2.01331	validation_1-rmse:2.01331
# [2868]	validation_0-rmse:2.01327	validation_1-rmse:2.01327
# [2869]	validation_0-rmse:2.01323	validation_1-rmse:2.01323
# [2870]	validation_0-rmse:2.01319	validation_1-rmse:2.01319
# [2871]	validation_0-rmse:2.01315	validation_1-rmse:2.01315
# [2872]	validation_0-rmse:2.01308	validation_1-rmse:2.01308
# [2873]	validation_0-rmse:2.01304	validation_1-rmse:2.01304
# [2874]	validation_0-rmse:2.01300	validation_1-rmse:2.01300
# [2875]	validation_0-rmse:2.01296	validation_1-rmse:2.01296
# [2876]	validation_0-rmse:2.01292	validation_1-rmse:2.01292
# [2877]	validation_0-rmse:2.01288	validation_1-rmse:2.01288
# [2878]	validation_0-rmse:2.01285	validation_1-rmse:2.01285
# [2879]	validation_0-rmse:2.01278	validation_1-rmse:2.01278
# [2880]	validation_0-rmse:2.01273	validation_1-rmse:2.01273
# [2881]	validation_0-rmse:2.01263	validation_1-rmse:2.01263
# [2882]	validation_0-rmse:2.01248	validation_1-rmse:2.01248
# [2883]	validation_0-rmse:2.01242	validation_1-rmse:2.01242
# [2884]	validation_0-rmse:2.01231	validation_1-rmse:2.01231
# [2885]	validation_0-rmse:2.01228	validation_1-rmse:2.01228
# [2886]	validation_0-rmse:2.01213	validation_1-rmse:2.01213
# [2887]	validation_0-rmse:2.01200	validation_1-rmse:2.01200
# [2888]	validation_0-rmse:2.01193	validation_1-rmse:2.01193
# [2889]	validation_0-rmse:2.01179	validation_1-rmse:2.01179
# [2890]	validation_0-rmse:2.01170	validation_1-rmse:2.01170
# [2891]	validation_0-rmse:2.01167	validation_1-rmse:2.01167
# [2892]	validation_0-rmse:2.01162	validation_1-rmse:2.01162
# [2893]	validation_0-rmse:2.01149	validation_1-rmse:2.01149
# [2894]	validation_0-rmse:2.01141	validation_1-rmse:2.01141
# [2895]	validation_0-rmse:2.01133	validation_1-rmse:2.01133
# [2896]	validation_0-rmse:2.01125	validation_1-rmse:2.01125
# [2897]	validation_0-rmse:2.01118	validation_1-rmse:2.01118
# [2898]	validation_0-rmse:2.01111	validation_1-rmse:2.01111
# [2899]	validation_0-rmse:2.01107	validation_1-rmse:2.01107
# [2900]	validation_0-rmse:2.01099	validation_1-rmse:2.01099
# [2901]	validation_0-rmse:2.01094	validation_1-rmse:2.01094
# [2902]	validation_0-rmse:2.01086	validation_1-rmse:2.01086
# [2903]	validation_0-rmse:2.01078	validation_1-rmse:2.01078
# [2904]	validation_0-rmse:2.01070	validation_1-rmse:2.01070
# [2905]	validation_0-rmse:2.01065	validation_1-rmse:2.01065
# [2906]	validation_0-rmse:2.01057	validation_1-rmse:2.01057
# [2907]	validation_0-rmse:2.01042	validation_1-rmse:2.01042
# [2908]	validation_0-rmse:2.01019	validation_1-rmse:2.01019
# [2909]	validation_0-rmse:2.01008	validation_1-rmse:2.01008
# [2910]	validation_0-rmse:2.00988	validation_1-rmse:2.00988
# [2911]	validation_0-rmse:2.00981	validation_1-rmse:2.00981
# [2912]	validation_0-rmse:2.00973	validation_1-rmse:2.00973
# [2913]	validation_0-rmse:2.00964	validation_1-rmse:2.00964
# [2914]	validation_0-rmse:2.00942	validation_1-rmse:2.00942
# [2915]	validation_0-rmse:2.00934	validation_1-rmse:2.00934
# [2916]	validation_0-rmse:2.00921	validation_1-rmse:2.00921
# [2917]	validation_0-rmse:2.00913	validation_1-rmse:2.00913
# [2918]	validation_0-rmse:2.00911	validation_1-rmse:2.00911
# [2919]	validation_0-rmse:2.00903	validation_1-rmse:2.00903
# [2920]	validation_0-rmse:2.00896	validation_1-rmse:2.00896
# [2921]	validation_0-rmse:2.00889	validation_1-rmse:2.00889
# [2922]	validation_0-rmse:2.00881	validation_1-rmse:2.00881
# [2923]	validation_0-rmse:2.00873	validation_1-rmse:2.00873
# [2924]	validation_0-rmse:2.00864	validation_1-rmse:2.00864
# [2925]	validation_0-rmse:2.00857	validation_1-rmse:2.00857
# [2926]	validation_0-rmse:2.00853	validation_1-rmse:2.00853
# [2927]	validation_0-rmse:2.00849	validation_1-rmse:2.00849
# [2928]	validation_0-rmse:2.00842	validation_1-rmse:2.00842
# [2929]	validation_0-rmse:2.00835	validation_1-rmse:2.00835
# [2930]	validation_0-rmse:2.00828	validation_1-rmse:2.00828
# [2931]	validation_0-rmse:2.00821	validation_1-rmse:2.00821
# [2932]	validation_0-rmse:2.00812	validation_1-rmse:2.00812
# [2933]	validation_0-rmse:2.00806	validation_1-rmse:2.00806
# [2934]	validation_0-rmse:2.00801	validation_1-rmse:2.00801
# [2935]	validation_0-rmse:2.00798	validation_1-rmse:2.00798
# [2936]	validation_0-rmse:2.00792	validation_1-rmse:2.00792
# [2937]	validation_0-rmse:2.00789	validation_1-rmse:2.00789
# [2938]	validation_0-rmse:2.00774	validation_1-rmse:2.00774
# [2939]	validation_0-rmse:2.00771	validation_1-rmse:2.00771
# [2940]	validation_0-rmse:2.00768	validation_1-rmse:2.00768
# [2941]	validation_0-rmse:2.00761	validation_1-rmse:2.00761
# [2942]	validation_0-rmse:2.00758	validation_1-rmse:2.00758
# [2943]	validation_0-rmse:2.00751	validation_1-rmse:2.00751
# [2944]	validation_0-rmse:2.00746	validation_1-rmse:2.00746
# [2945]	validation_0-rmse:2.00741	validation_1-rmse:2.00741
# [2946]	validation_0-rmse:2.00737	validation_1-rmse:2.00737
# [2947]	validation_0-rmse:2.00730	validation_1-rmse:2.00730
# [2948]	validation_0-rmse:2.00726	validation_1-rmse:2.00726
# [2949]	validation_0-rmse:2.00719	validation_1-rmse:2.00719
# [2950]	validation_0-rmse:2.00718	validation_1-rmse:2.00718
# [2951]	validation_0-rmse:2.00711	validation_1-rmse:2.00711
# [2952]	validation_0-rmse:2.00703	validation_1-rmse:2.00703
# [2953]	validation_0-rmse:2.00698	validation_1-rmse:2.00698
# [2954]	validation_0-rmse:2.00682	validation_1-rmse:2.00682
# [2955]	validation_0-rmse:2.00676	validation_1-rmse:2.00676
# [2956]	validation_0-rmse:2.00671	validation_1-rmse:2.00671
# [2957]	validation_0-rmse:2.00665	validation_1-rmse:2.00665
# [2958]	validation_0-rmse:2.00660	validation_1-rmse:2.00660
# [2959]	validation_0-rmse:2.00658	validation_1-rmse:2.00658
# [2960]	validation_0-rmse:2.00653	validation_1-rmse:2.00653
# [2961]	validation_0-rmse:2.00648	validation_1-rmse:2.00648
# [2962]	validation_0-rmse:2.00634	validation_1-rmse:2.00634
# [2963]	validation_0-rmse:2.00629	validation_1-rmse:2.00629
# [2964]	validation_0-rmse:2.00618	validation_1-rmse:2.00618
# [2965]	validation_0-rmse:2.00612	validation_1-rmse:2.00612
# [2966]	validation_0-rmse:2.00601	validation_1-rmse:2.00601
# [2967]	validation_0-rmse:2.00598	validation_1-rmse:2.00598
# [2968]	validation_0-rmse:2.00594	validation_1-rmse:2.00594
# [2969]	validation_0-rmse:2.00584	validation_1-rmse:2.00584
# [2970]	validation_0-rmse:2.00579	validation_1-rmse:2.00579
# [2971]	validation_0-rmse:2.00570	validation_1-rmse:2.00570
# [2972]	validation_0-rmse:2.00565	validation_1-rmse:2.00565
# [2973]	validation_0-rmse:2.00558	validation_1-rmse:2.00558
# [2974]	validation_0-rmse:2.00541	validation_1-rmse:2.00541
# [2975]	validation_0-rmse:2.00538	validation_1-rmse:2.00538
# [2976]	validation_0-rmse:2.00532	validation_1-rmse:2.00532
# [2977]	validation_0-rmse:2.00530	validation_1-rmse:2.00530
# [2978]	validation_0-rmse:2.00524	validation_1-rmse:2.00524
# [2979]	validation_0-rmse:2.00515	validation_1-rmse:2.00515
# [2980]	validation_0-rmse:2.00507	validation_1-rmse:2.00507
# [2981]	validation_0-rmse:2.00499	validation_1-rmse:2.00499
# [2982]	validation_0-rmse:2.00491	validation_1-rmse:2.00491
# [2983]	validation_0-rmse:2.00485	validation_1-rmse:2.00485
# [2984]	validation_0-rmse:2.00476	validation_1-rmse:2.00476
# [2985]	validation_0-rmse:2.00474	validation_1-rmse:2.00474
# [2986]	validation_0-rmse:2.00471	validation_1-rmse:2.00471
# [2987]	validation_0-rmse:2.00468	validation_1-rmse:2.00468
# [2988]	validation_0-rmse:2.00460	validation_1-rmse:2.00460
# [2989]	validation_0-rmse:2.00457	validation_1-rmse:2.00457
# [2990]	validation_0-rmse:2.00450	validation_1-rmse:2.00450
# [2991]	validation_0-rmse:2.00443	validation_1-rmse:2.00443
# [2992]	validation_0-rmse:2.00435	validation_1-rmse:2.00435
# [2993]	validation_0-rmse:2.00422	validation_1-rmse:2.00422
# [2994]	validation_0-rmse:2.00417	validation_1-rmse:2.00417
# [2995]	validation_0-rmse:2.00397	validation_1-rmse:2.00397
# [2996]	validation_0-rmse:2.00386	validation_1-rmse:2.00386
# [2997]	validation_0-rmse:2.00369	validation_1-rmse:2.00369
# [2998]	validation_0-rmse:2.00352	validation_1-rmse:2.00352
# [2999]	validation_0-rmse:2.00336	validation_1-rmse:2.00336
# >>> Predicting target NEE_L3.1_L3.3_CUT_50_QCF_gfXG using fallback model ...
# >>> Combining predictions from full model and fallback model ...
# Collecting results for 2024 ...
# Collecting results for 2025 ...
# Collecting results for 2026 ...

# %% [markdown]
# ## 🔸MDS (Marginal Distribution Sampling)

# %%
fpc.level41_mds(
    swin="SW_IN_POT",
    ta="TA_EP",
    vpd="VPD_EP",
    swin_tol=[20, 50],
    ta_tol=2.5,
    vpd_tol=0.5,
    avg_min_n_vals=5
)
# Out:
# ==============================
# Starting MDS gap-filling of flux NEE_L3.1_L3.3_CUT_50_QCF.
# MDS gap-filling quality 1    using SW_IN, TA, VPD in 7 days window ...
# MDS gap-filling quality 2    using SW_IN, TA, VPD in 14 days window ...
# MDS gap-filling quality 3    using SW_IN in 7 days window ...
# MDS gap-filling quality 4    using mean diurnal cycle of flux in 0 days, 1 hours window ...
# MDS gap-filling quality 5    using mean diurnal cycle of flux in 1 days, 1 hours window ...
# MDS gap-filling quality 6    using SW_IN, TA, VPD in 21 days window ...
# MDS gap-filling quality 7    using SW_IN, TA, VPD in 28 days window ...
# MDS gap-filling quality 8    using SW_IN in 14 days window ...
# MDS gap-filling quality 9    using SW_IN, TA, VPD in 35 days window ...
# MDS gap-filling quality 10    using SW_IN, TA, VPD in 42 days window ...
# MDS gap-filling quality 11    using SW_IN, TA, VPD in 49 days window ...
# MDS gap-filling quality 12    using SW_IN, TA, VPD in 56 days window ...
# MDS gap-filling quality 13    using SW_IN, TA, VPD in 63 days window ...
# MDS gap-filling quality 14    using SW_IN, TA, VPD in 70 days window ...
# MDS gap-filling quality 15    using SW_IN, TA, VPD in 77 days window ...
# MDS gap-filling quality 16    using SW_IN, TA, VPD in 84 days window ...
# MDS gap-filling quality 17    using SW_IN, TA, VPD in 91 days window ...
# MDS gap-filling quality 18    using SW_IN, TA, VPD in 98 days window ...
# MDS gap-filling quality 19    using SW_IN, TA, VPD in 105 days window ...
# MDS gap-filling quality 20    using SW_IN, TA, VPD in 112 days window ...
# MDS gap-filling quality 21    using SW_IN, TA, VPD in 119 days window ...
# MDS gap-filling quality 22    using SW_IN, TA, VPD in 126 days window ...
# MDS gap-filling quality 23    using SW_IN, TA, VPD in 133 days window ...
# MDS gap-filling quality 24    using SW_IN, TA, VPD in 140 days window ...
# MDS gap-filling quality 25    using SW_IN in 21 days window ...
# MDS gap-filling quality 26    using SW_IN in 28 days window ...
# MDS gap-filling quality 27    using SW_IN in 35 days window ...
# MDS gap-filling quality 28    using SW_IN in 42 days window ...
# MDS gap-filling quality 29    using SW_IN in 49 days window ...
# MDS gap-filling quality 30    using SW_IN in 56 days window ...
# MDS gap-filling quality 31    using SW_IN in 63 days window ...
# MDS gap-filling quality 32    using SW_IN in 70 days window ...
# MDS gap-filling done.

# %% [markdown]
# ## Get results
# - Results from the flux processing chain can be accessed using `.get_data()`
# - This returns a dataframe containing all input data and all newly generated variables, such as quality flags, quality-filtered fluxes and gap-filled fluxes

# %%
results = fpc.get_data(verbose=1)
results
# Out:
# NEW VARIABLES FROM FLUX PROCESSING CHAIN:
# ++ FLAG_L2_FC_MISSING_TEST
# ++ FLAG_L2_FC_SSITC_TEST
# ++ FLAG_L2_FC_SCF_TEST
# ++ FLAG_L2_FC_SIGNAL_STRENGTH_TEST
# ++ FLAG_L2_FC_CO2_VM97_SPIKE_HF_TEST
# ++ FLAG_L2_FC_CO2_VM97_DROPOUT_TEST
# ++ SUM_L2_FC_HARDFLAGS
# ++ SUM_L2_FC_SOFTFLAGS
# ++ SUM_L2_FC_FLAGS
# ++ FLAG_L2_FC_QCF
# ++ FC_L2_QCF
# ++ FC_L2_QCF0
# ++ SC_SINGLE_gfRMED_L3.1
# ++ FLAG_SC_SINGLE_gfRMED_L3.1_ISFILLED
# ++ NEE_L3.1
# ++ NEE_L3.1_QCF
# ++ NEE_L3.1_QCF0
# ++ FLAG_L3.2_NEE_L3.1_QCF_OUTLIER_HAMPELDTNT_TEST
# ++ SUM_L3.2_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.2_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.2_NEE_L3.1_FLAGS
# ++ FLAG_L3.2_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.2_QCF
# ++ NEE_L3.1_L3.2_QCF0
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_USTAR_TEST
# ++ SUM_L3.3_CUT_50_NEE_L3.1_HARDFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_SOFTFLAGS
# ++ SUM_L3.3_CUT_50_NEE_L3.1_FLAGS
# ++ FLAG_L3.3_CUT_50_NEE_L3.1_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF
# ++ NEE_L3.1_L3.3_CUT_50_QCF0
# ++ NEE_L3.1_L3.3_CUT_50_QCF_gfXG
# ++ FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfXG_ISFILLED
# ++ NEE_L3.1_L3.3_CUT_50_QCF_gfXG
# ++ FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfXG_ISFILLED
# ++ NEE_L3.1_L3.3_CUT_50_QCF_gfMDS
# ++ FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfMDS_ISFILLED
# No variables in input data were overwritten, only new variables added.
#                        AIR_MV  AIR_DENSITY  AIR_RHO_CP   AIR_CP  AOA_METHOD  AXES_ROTATION_METHOD  ...  NEE_L3.1_L3.3_CUT_50_QCF_gfXG  NEE_L3.1_L3.3_CUT_50_QCF_gfXG  FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfXG_ISFILLED  FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfXG_ISFILLED  NEE_L3.1_L3.3_CUT_50_QCF_gfMDS  FLAG_NEE_L3.1_L3.3_CUT_50_QCF_gfMDS_ISFILLED
# TIMESTAMP_MIDDLE                                                                                   ...
# 2024-02-06 19:15:00  0.024925      1.16151     1172.76  1009.69         0.0                   1.0  ...                       6.760934                       0.799076                                          2.0                                          2.0                        2.156673                                           0.0
# 2024-02-06 19:45:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                       6.760934                       0.799076                                          2.0                                          2.0                        5.218210                                           3.0
# 2024-02-06 20:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                       3.769886                       0.776510                                          2.0                                          2.0                        5.218210                                           3.0
# 2024-02-06 20:45:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                       3.769886                       0.776510                                          2.0                                          2.0                        5.218210                                           3.0
# 2024-02-06 21:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                       4.751514                       2.521082                                          2.0                                          2.0                        5.218210                                           3.0
# ...                       ...          ...         ...      ...         ...                   ...  ...                            ...                            ...                                          ...                                          ...                             ...                                           ...
# 2026-03-31 22:45:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                       0.509967                       1.093198                                          2.0                                          2.0                        0.112224                                           3.0
# 2026-03-31 23:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                       1.828981                       1.785416                                          2.0                                          2.0                        0.112224                                           3.0
# 2026-03-31 23:45:00  0.023961      1.20871     1215.82  1005.88         0.0                   1.0  ...                       1.828981                       1.785416                                          2.0                                          2.0                        0.112224                                           3.0
# 2026-04-01 00:15:00       NaN          NaN         NaN      NaN         NaN                   NaN  ...                      -0.588926                      -1.320766                                          2.0                                          2.0                        0.112224                                           3.0
# 2026-04-01 00:45:00  0.023944      1.20915     1220.27  1009.20         0.0                   1.0  ...                      -0.588926                      -1.320766                                          2.0                                          2.0                        0.112224                                           3.0
#
# [37644 rows x 523 columns]

# %% [markdown]
# ## Model scores

# %% [markdown]
# ### Model scores and details on test data

# %%
# Show train/test details
print(fpc.report_traintest_model_scores())
print(fpc.report_traintest_details())
# fpc.report_traintest_model_scores(outpath=".")  # Save in current folder
# fpc.report_traintest_details(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES from TRAINING/TESTING (long_term_xgboost):
#  trained on training data, tested on unseen test data CUT_50
#             2024       2025       2026
# mae     2.696671   2.696671   2.696671
# medae   1.681093   1.681093   1.681093
# mse    18.654256  18.654256  18.654256
# rmse    4.319057   4.319057   4.319057
# mape    3.373246   3.373246   3.373246
# maxe   33.042939  33.042939  33.042939
# r2      0.647110   0.647110   0.647110
# mds CUT_50 does not have train/test model scores.
# None
#
# DETAILS from TRAINING/TESTING (long_term_xgboost CUT_50):
#  trained on training data, tested on unseen test data
#                                                         2024                                               2025                                               2026
# train_df                           TA_EP   SW_IN_POT   VP...                          TA_EP   SW_IN_POT   VP...                          TA_EP   SW_IN_POT   VP...
# test_df                            TA_EP   SW_IN_POT    V...                          TA_EP   SW_IN_POT    V...                          TA_EP   SW_IN_POT    V...
# test_size                                               0.25                                               0.25                                               0.25
# X_names    [TA_EP, SW_IN_POT, VPD_EP, .TA_EP-1, .TA_EP+1,...  [TA_EP, SW_IN_POT, VPD_EP, .TA_EP-1, .TA_EP+1,...  [TA_EP, SW_IN_POT, VPD_EP, .TA_EP-1, .TA_EP+1,...
# model      XGBRegressor(base_score=None, booster=None, ca...  XGBRegressor(base_score=None, booster=None, ca...  XGBRegressor(base_score=None, booster=None, ca...
# mds CUT_50 does not have train/test details.
# None

# %% [markdown]
# ### Model scores on all data

# %%
fpc.report_gapfilling_model_scores()
# fpc.report_gapfilling_model_scores(outpath=".")  # Save in current folder
# Out:
# MODEL SCORES (long_term_xgboost): CUT_50
#             2024       2025       2026
# mae     1.402495   1.402495   1.402495
# medae   0.849162   0.849162   0.849162
# mse     5.984651   5.984651   5.984651
# rmse    2.446355   2.446355   2.446355
# mape    1.345090   1.345090   1.345090
# maxe   33.042939  33.042939  33.042939
# r2      0.884284   0.884284   0.884284
#
# MODEL SCORES (mds): CUT_50
#                                            0
# mae                                 3.287072
# medae                               1.993782
# mse                                26.082360
# rmse                                5.107089
# mape                                3.877254
# maxe                               35.620041
# r2                                  0.551097
# mean_quality_flag_gap_predictions   4.247997

# %% [markdown]
# During long-term gap-filling, different years are pooled together to predict one central year, i.e., multiple models are used.
# The used data pools can be display with:

# %%
fpc.report_gapfilling_poolyears()
# Out:
# DATA POOLS USED FOR MACHINE-LEARNING GAP-FILLING:
# 2024: long_term_xgboost used data from [2024, 2025, 2026] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfXG
# 2025: long_term_xgboost used data from [2024, 2025, 2026] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfXG
# 2026: long_term_xgboost used data from [2024, 2025, 2026] for gap-filling NEE_L3.1_L3.3_CUT_50_QCF and producing --> NEE_L3.1_L3.3_CUT_50_QCF_gfXG
# mds CUT_50 did not use poolyears.

# %%
fpc.report_gapfilling_feature_importances()  # Save in current folder
# fpc.report_gapfilling_feature_importances(outpath=".")  # Save in current folder
# Out:
# FEATURE IMPORTANCES (long_term_xgboost): CUT_50
# YEAR                         2024      2025      2026
# FEATURE
# .SW_IN_POT+1             4.000769  4.000769  4.000769
# .MONTH_COS               0.486947  0.486947  0.486947
# .SW_IN_POT_ROLLMEDIAN48  0.334366  0.334366  0.334366
# .VPD_EP+1                0.320015  0.320015  0.320015
# .TA_EP_ROLLMIN24         0.233886  0.233886  0.233886
# ...                           ...       ...       ...
# .SW_IN_POT_ROLLMIN24     0.003459  0.003459  0.003459
# .TA_EP_POL2              0.002479  0.002479  0.002479
# .SW_IN_POT_POL2          0.000000  0.000000  0.000000
# .SW_IN_POT_ROLLMIN48     0.000000  0.000000  0.000000
# .VPD_EP_POL2             0.000000  0.000000  0.000000
#
# [87 rows x 3 columns]
# mds CUT_50 does not have feature importances.

# %% [markdown]
# ## Names of gap-filled variables

# %%
print("Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:")
fpc.report_gapfilling_variables()
# Out:
# Used model, USTAR scenario, non-gapfilled variable and gap-filled variable:
# long_term_xgboost (CUT_50): NEE_L3.1_L3.3_CUT_50_QCF -> NEE_L3.1_L3.3_CUT_50_QCF_gfXG
# mds (CUT_50): NEE_L3.1_L3.3_CUT_50_QCF -> NEE_L3.1_L3.3_CUT_50_QCF_gfMDS

# %%
gapfilled_names = fpc.get_gapfilled_names()
gapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF_gfXG', 'NEE_L3.1_L3.3_CUT_50_QCF_gfMDS']

# %% [markdown]
# Gap-filled data can also be accessed directly. To get all gap-filled variables and also the same variables before gap-filling in a dataframe, use `.get_gapfilled_variables()`:

# %%
gapfilled_vars = fpc.get_gapfilled_variables()
gapfilled_vars.head(3)
# Out:
#                      NEE_L3.1_L3.3_CUT_50_QCF_gfXG  NEE_L3.1_L3.3_CUT_50_QCF_gfXG  NEE_L3.1_L3.3_CUT_50_QCF_gfMDS  NEE_L3.1_L3.3_CUT_50_QCF  NEE_L3.1_L3.3_CUT_50_QCF
# TIMESTAMP_MIDDLE
# 2024-02-06 19:15:00                       6.760934                       0.799076                        2.156673                  2.156673                  2.156673
# 2024-02-06 19:45:00                       6.760934                       0.799076                        5.218210                       NaN                       NaN
# 2024-02-06 20:15:00                       3.769886                       0.776510                        5.218210                       NaN                       NaN

# %% [markdown]
# The names of the flux that was gap-filled can be accessed like this:

# %%
nongapfilled_names = fpc.get_nongapfilled_names()
nongapfilled_names
# Out:
# ['NEE_L3.1_L3.3_CUT_50_QCF', 'NEE_L3.1_L3.3_CUT_50_QCF']

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Heatmaps

# %%
fpc.showplot_gapfilled_heatmap()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17852\199514501.py in ?()
# ----> 1 fpc.showplot_gapfilled_heatmap()
#
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py in ?(self, vmin, vmax)
#     497                 series_ngf = series_ngf.loc[:, ~series_ngf.columns.duplicated()].copy()
#     498                 series_ngf = series_ngf.squeeze()
#     499
#     500             hm = HeatmapDateTime(ax=ax_ngf, series=series_ngf, vmin=vmin, vmax=vmax).plot()
# --> 501             hm = HeatmapDateTime(ax=ax_gf, series=gfvars[g], vmin=vmin, vmax=vmax).plot()
#     502             fig.tight_layout()
#     503             fig.show()
#
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\heatmap_datetime.py in ?(self, series, **kwargs)
#      74         _orientation = kwargs.get('ax_orientation', 'vertical')
#      75         _heatmaptype = 'datetime' if _orientation == 'vertical' else 'datetime_horizontal'
#      76         super().__init__(heatmaptype=_heatmaptype, **kwargs)
#      77         self.series = series.copy()
# ---> 78         self._prepare_data()
#
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\heatmap_datetime.py in ?(self)
#      87         4. Pivots the DataFrame to create the grid for the heatmap, with 'DATE' or 'TIME'
#      88            as the index and the other as columns, based on `self.ax_orientation`.
#      89         5. Calls `_set_bounds` to extend the x and y data for proper heatmap cell rendering.
#      90         """
# ---> 91         self.series.name = self.series.name if self.series.name else "data"  # Time series must have a name
#      92         self.series = self._setup_timestamp(series=self.series)
#      93
#      94         # Data for plotting
#
# ~\AppData\Local\miniconda3\envs\hon_fp\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %% [markdown]
# ### Cumulatives per year

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17852\2799077726.py in ?()
# ----> 1 fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=True)
#
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py in ?(self, gain, units, per_year, start_year, end_year)
#     521         gapfilled_vars = self.get_gapfilled_names()
#     522         gfvars = self.get_gapfilled_variables()[gapfilled_vars]
#     523         if per_year:
#     524             for g in gfvars:
# --> 525                 CumulativeYear(
#     526                     series=gfvars[g].multiply(gain),
#     527                     series_units=units,
#     528                     yearly_end_date=None,
#
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py in ?(self, series, series_units, yearly_end_date, start_year, end_year, show_reference, excl_years_from_reference, highlight_year, highlight_year_color)
#      32         """
#      33
#      34         self.series = series.copy()
#      35         self.series_units = series_units
# ---> 36         self.varname = series.name
#      37         self.start_year = start_year if start_year else self.series.index.year.min()
#      38         self.end_year = end_year if end_year else self.series.index.year.max()
#      39         self.yearly_end_date = yearly_end_date
#
# ~\AppData\Local\miniconda3\envs\hon_fp\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %% [markdown]
# ### Cumulative across all data

# %%
fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 fpc.showplot_gapfilled_cumulative(gain=0.02161926, units=r'($\mathrm{gC\ m^{-2}}$)', per_year=False)
#
# File F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\pkgs\fluxprocessingchain\fluxprocessingchain.py:544, in FluxProcessingChain.showplot_gapfilled_cumulative(self, gain, units, per_year, start_year, end_year)
#     538 df = gfvars[gapfilled_vars].copy()
#     539 df = df.multiply(gain)
#     540 Cumulative(
#     541     df=df,
#     542     units=units,
#     543     start_year=start_year,
# --> 544     end_year=end_year).plot()
#
# File F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\cumulative.py:228, in Cumulative.plot(self, showplot, digits_after_comma, show_grid, show_legend, ylabel, show_title)
#     226 for ix, col in enumerate(self.cumulative):
#     227     series = self.cumulative[col]
# --> 228     label = f"{col}: {series.dropna().iloc[-1]:.{digits_after_comma}f}"
#     229     lw = theme.WIDTH_LINE_DEFAULT
#     230     color = color_list[ix]
#
# TypeError: unsupported format string passed to Series.__format__

# %% [markdown]
# ### ML Feature ranks per year (machine learning models only)

# %%
fpc.showplot_feature_ranks_per_year()

# %% [markdown]
# ### MDS gap-filling qualities (MDS only, otherwise skipped)

# %%
fpc.showplot_mds_gapfilling_qualities()

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # SAVE RESULTS TO FILE

# %% [markdown]
# - Save results to file for futher processing
# - This can be useful if you want to use the data in another software, e.g. continuing post-processing using the library `ReddyProc` in `R`
# - `Parquet` format is recommended for large datasets

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 1: Save complete data (input data and results) to CSV (large and slow)

# %%
# results.to_csv("FluxProcessingChain_L4.1.csv")

# %% [markdown]
# </br>

# %% [markdown]
# ## Option 2: Save input data and results to Parquet (small and fast)
# - Needed if you want to continue post-processing in notebooks
# - Can also be used in `R` with the `arrow` package

# %%
# save_parquet(data=results, filename="FluxProcessingChain_L4.1")

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# <div style="
#     height: 30px; /* Adjust height as desired */
#     background: linear-gradient(135deg, #FF6B6B 0%, #FFE66D 100%); /* Warm gradient */
#     background-image:
#         radial-gradient(circle at 100% 150%, #FF6B6B 0%, #FFE66D 100%),
#         linear-gradient(to right, rgba(255,255,255,0.1) 1px, transparent 1px),
#         linear-gradient(to bottom, rgba(255,255,255,0.1) 1px, transparent 1px);
#     background-size: 100% 100%, 15px 15px, 15px 15px; /* Adjust pattern size */
#     border-radius: 8px;
#     box-shadow: 0 4px 8px rgba(0,0,0,0.1);
# "></div>

# %% [markdown]
# # ✅END OF NOTEBOOK

# %% [markdown]
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
